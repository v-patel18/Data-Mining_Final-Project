# %% [markdown]
# <a href="https://colab.research.google.com/github/v-patel18/Data-Mining_Final-Project/blob/master/Pneumonia_Detection_Challenge_Trial_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Install necessary packages
# !pip3 install -q pydicom 
# !pip3 install -q tqdm 
# !pip3 install -q imgaug
# Out:
#      |████████████████████████████████| 7.0MB 2.8MB/s

# %%
#Use Kaggle API to download data
# !pip3 install -q kaggle

# %%
#Import necessary libraries
import os 
import sys

import random
import math
import numpy as np
import cv2
import matplotlib.pyplot as plt
import json
import pydicom
from imgaug import augmenters as iaa
from tqdm import tqdm
import pandas as pd 
import glob

# %%
# Use Kaggle credentials to download data
os.environ['KAGGLE_USERNAME']="vasvip"
os.environ['KAGGLE_KEY']="39829c7c09776b1754776f543a2459d1"

# %%
# Root directory of the project
ROOT_DIR = os.path.abspath('/Pneumonia_Detection')

# Directory to save logs and trained model
MODEL_DIR = os.path.join(ROOT_DIR, 'working')

if not os.path.exists(ROOT_DIR):
    os.makedirs(ROOT_DIR)
os.chdir(ROOT_DIR)

# %%
#Download dataset for the competition
# !kaggle competitions download -c rsna-pneumonia-detection-challenge
# Out:
# Downloading stage_2_detailed_class_info.csv.zip to /Pneumonia_Detection
#   0% 0.00/583k [00:00<?, ?B/s]
# 100% 583k/583k [00:00<00:00, 79.8MB/s]
# Downloading stage_2_sample_submission.csv to /Pneumonia_Detection
#   0% 0.00/155k [00:00<?, ?B/s]
# 100% 155k/155k [00:00<00:00, 49.9MB/s]
# Downloading stage_2_train_labels.csv.zip to /Pneumonia_Detection
#   0% 0.00/661k [00:00<?, ?B/s]
# 100% 661k/661k [00:00<00:00, 91.6MB/s]
# Downloading stage_2_test_images.zip to /Pneumonia_Detection
#  98% 369M/377M [00:03<00:00, 112MB/s]
# 100% 377M/377M [00:03<00:00, 112MB/s]
# Downloading stage_2_train_images.zip to /Pneumonia_Detection
#  99% 3.27G/3.29G [00:26<00:00, 101MB/s]
# 100% 3.29G/3.29G [00:26<00:00, 132MB/s]
# Downloading GCP%20Credits%20Request%20Link%20-%20RSNA.txt to /Pneumonia_Detection
#   0% 0.00/55.0 [00:00<?, ?B/s]
# 100% 55.0/55.0 [00:00<00:00, 56.6kB/s]

# %%
# Unzip the downloaded files
# !unzip -q -o stage_2_test_images.zip -d stage_2_test_images
# !unzip -q -o stage_2_train_images.zip -d stage_2_train_images
# !unzip -q -o stage_2_train_labels.csv.zip

# %% [markdown]
# ## **Problem and Approach**
#
# RSNA Pneumonia Detection Challenge is a problem that requires for the detection of a bounding box that encompasses a pneumonia containing region. Hence, it is not a pure classification problem; it is rather a regression problem asking for the location and size of the region containing pneumonia in chest radiographs.
#
# Convolutional Neural Networks (CNN) are

# %% [markdown]
# **Install Matterport's Mask-RCNN implementation from GitHub**

# %%
os.chdir(ROOT_DIR)
# !git clone https://github.com/matterport/Mask_RCNN.git
os.chdir('Mask_RCNN')
# !python setup.py -q install
# Out:
# Cloning into 'Mask_RCNN'...
# remote: Enumerating objects: 956, done.
# remote: Total 956 (delta 0), reused 0 (delta 0), pack-reused 956
# Receiving objects: 100% (956/956), 119.70 MiB | 40.39 MiB/s, done.
# Resolving deltas: 100% (555/555), done.
# WARNING:root:Fail load requirements file, so using default ones.
# zip_safe flag not set; analyzing archive contents...

# %%
# Import Mask RCNN
sys.path.append(os.path.join(ROOT_DIR, 'Mask_RCNN'))  # To find local version of the library
from mrcnn.config import Config
from mrcnn import utils
import mrcnn.model as modellib
from mrcnn import visualize
from mrcnn.model import log
# Out:
# Using TensorFlow backend.

# %%
train_dicom_dir = os.path.join(ROOT_DIR, 'stage_2_train_images')
test_dicom_dir = os.path.join(ROOT_DIR, 'stage_2_test_images')

# %%
def get_dicom_fps(dicom_dir):
    dicom_fps = glob.glob(dicom_dir+'/'+'*.dcm')
    return list(set(dicom_fps))

def parse_dataset(dicom_dir, anns): 
    image_fps = get_dicom_fps(dicom_dir)
    image_annotations = {fp: [] for fp in image_fps}
    for index, row in anns.iterrows(): 
        fp = os.path.join(dicom_dir, row['patientId']+'.dcm')
        image_annotations[fp].append(row)
    return image_fps, image_annotations

# %%
class DetectorConfig(Config):
    """Configuration for training pneumonia detection on the RSNA pneumonia dataset.
    Overrides values in the base Config class.
    """
    
    # Give the configuration a recognizable name  
    NAME = 'pneumonia'
    
    # Train on 1 GPU and 8 images per GPU. We can put multiple images on each
    # GPU because the images are small. Batch size is 8 (GPUs * images/GPU).
    GPU_COUNT = 1
    IMAGES_PER_GPU = 8 
    
    BACKBONE = 'resnet50'
    
    NUM_CLASSES = 2  # background + 1 pneumonia classes
    
    # Use small images for faster training. Set the limits of the small side
    # the large side, and that determines the image shape.
    IMAGE_MIN_DIM = 256
    IMAGE_MAX_DIM = 256
    
    RPN_ANCHOR_SCALES = (16, 32, 64, 128)
    
    TRAIN_ROIS_PER_IMAGE = 32
    
    MAX_GT_INSTANCES = 3
    
    DETECTION_MAX_INSTANCES = 3
    DETECTION_MIN_CONFIDENCE = 0.8
    DETECTION_NMS_THRESHOLD = 0.05
    
    RPN_TRAIN_ANCHORS_PER_IMAGE = 256
    STEPS_PER_EPOCH = 150 
    TOP_DOWN_PYRAMID_SIZE = 256
    
    
config = DetectorConfig()
config.display()
# Out:
# Configurations:
# BACKBONE                       resnet50
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     8
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        3
# DETECTION_MIN_CONFIDENCE       0.8
# DETECTION_NMS_THRESHOLD        0.05
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 8
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  256
# IMAGE_META_SIZE                14
# IMAGE_MIN_DIM                  256
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [256 256   3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               3
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           pneumonia
# NUM_CLASSES                    2
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# PRE_NMS_LIMIT                  6000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (16, 32, 64, 128)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                150
# TOP_DOWN_PYRAMID_SIZE          256
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           32
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               50
# WEIGHT_DECAY                   0.0001

# %%
class DetectorDataset(utils.Dataset):
    """Dataset class for training pneumonia detection on the RSNA pneumonia dataset.
    """

    def __init__(self, image_fps, image_annotations, orig_height, orig_width):
        super().__init__(self)
        
        # Add classes
        self.add_class('pneumonia', 1, 'Lung Opacity')
   
        # add images 
        for i, fp in enumerate(image_fps):
            annotations = image_annotations[fp]
            self.add_image('pneumonia', image_id=i, path=fp, 
                           annotations=annotations, orig_height=orig_height, orig_width=orig_width)
            
    def image_reference(self, image_id):
        info = self.image_info[image_id]
        return info['path']

    def load_image(self, image_id):
        info = self.image_info[image_id]
        fp = info['path']
        ds = pydicom.read_file(fp)
        image = ds.pixel_array
        # If grayscale. Convert to RGB for consistency.
        if len(image.shape) != 3 or image.shape[2] != 3:
            image = np.stack((image,) * 3, -1)
        return image

    def load_mask(self, image_id):
        info = self.image_info[image_id]
        annotations = info['annotations']
        count = len(annotations)
        if count == 0:
            mask = np.zeros((info['orig_height'], info['orig_width'], 1), dtype=np.uint8)
            class_ids = np.zeros((1,), dtype=np.int32)
        else:
            mask = np.zeros((info['orig_height'], info['orig_width'], count), dtype=np.uint8)
            class_ids = np.zeros((count,), dtype=np.int32)
            for i, a in enumerate(annotations):
                if a['Target'] == 1:
                    x = int(a['x'])
                    y = int(a['y'])
                    w = int(a['width'])
                    h = int(a['height'])
                    mask_instance = mask[:, :, i].copy()
                    cv2.rectangle(mask_instance, (x, y), (x+w, y+h), 255, -1)
                    mask[:, :, i] = mask_instance
                    class_ids[i] = 1
        return mask.astype(np.bool), class_ids.astype(np.int32)

# %%
# training dataset
anns = pd.read_csv(os.path.join(ROOT_DIR, 'stage_2_train_labels.csv'))
anns.head(6)
# Out:
#                               patientId      x      y  width  height  Target
# 0  0004cfab-14fd-4e49-80ba-63a80b6bddd6    NaN    NaN    NaN     NaN       0
# 1  00313ee0-9eaa-42f4-b0ab-c148ed3241cd    NaN    NaN    NaN     NaN       0
# 2  00322d4d-1c29-4943-afc9-b6754be640eb    NaN    NaN    NaN     NaN       0
# 3  003d8fa0-6bf1-40ed-b54c-ac657f8495c5    NaN    NaN    NaN     NaN       0
# 4  00436515-870c-4b36-a041-de91049b9ab4  264.0  152.0  213.0   379.0       1
# 5  00436515-870c-4b36-a041-de91049b9ab4  562.0  152.0  256.0   453.0       1

# %%
image_fps, image_annotations = parse_dataset(train_dicom_dir, anns=anns)

# %%
ds = pydicom.read_file(image_fps[0]) # read dicom image from filepath 
image = ds.pixel_array # get image array

# %%
ds
# Out:
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0016) SOP Class UID                       UI: Secondary Capture Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.276.0.7230010.3.1.4.8323329.1701.1517874292.366626
# (0008, 0020) Study Date                          DA: '19010101'
# (0008, 0030) Study Time                          TM: '000000.00'
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'CR'
# (0008, 0064) Conversion Type                     CS: 'WSD'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 103e) Series Description                  LO: 'view: PA'
# (0010, 0010) Patient's Name                      PN: '64f134d6-370e-46f5-a16e-0c9832f1eda9'
# (0010, 0020) Patient ID                          LO: '64f134d6-370e-46f5-a16e-0c9832f1eda9'
# (0010, 0030) Patient's Birth Date                DA: ''
# (0010, 0040) Patient's Sex                       CS: 'M'
# (0010, 1010) Patient's Age                       AS: '54'
# (0018, 0015) Body Part Examined                  CS: 'CHEST'
# (0018, 5101) View Position                       CS: 'PA'
# (0020, 000d) Study Instance UID                  UI: 1.2.276.0.7230010.3.1.2.8323329.1701.1517874292.366625
# (0020, 000e) Series Instance UID                 UI: 1.2.276.0.7230010.3.1.3.8323329.1701.1517874292.366624
# (0020, 0010) Study ID                            SH: ''
# (0020, 0011) Series Number                       IS: "1"
# (0020, 0013) Instance Number                     IS: "1"
# (0020, 0020) Patient Orientation                 CS: ''
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 1024
# (0028, 0011) Columns                             US: 1024
# (0028, 0030) Pixel Spacing                       DS: ['0.168', '0.168']
# (0028, 0100) Bits Allocated                      US: 8
# (0028, 0101) Bits Stored                         US: 8
# (0028, 0102) High Bit                            US: 7
# (0028, 0103) Pixel Representation                US: 0
# (0028, 2110) Lossy Image Compression             CS: '01'
# (0028, 2114) Lossy Image Compression Method      CS: 'ISO_10918_1'
# (7fe0, 0010) Pixel Data                          OB: Array of 122502 bytes

# %%
# Original DICOM image size: 1024 x 1024
ORIG_SIZE = 1024

# %% [markdown]
# **Split data into training and validation datasets**

# %%
######################################################################
# Modify this line to use more or fewer images for training/validation. 
# To use all images, do: image_fps_list = list(image_fps)
image_fps_list = list(image_fps) 
#####################################################################

# split dataset into training vs. validation dataset 
# split ratio is set to 0.9 vs. 0.1 (train vs. validation, respectively)
sorted(image_fps_list)
random.seed(42)
random.shuffle(image_fps_list)

validation_split = 0.1
split_index = int((1 - validation_split) * len(image_fps_list))

image_fps_train = image_fps_list[:split_index]
image_fps_val = image_fps_list[split_index:]

print(len(image_fps_train), len(image_fps_val))
# Out:
# 24015 2669

# %%
# prepare the training dataset
dataset_train = DetectorDataset(image_fps_train, image_annotations, ORIG_SIZE, ORIG_SIZE)
dataset_train.prepare()

# %%
# Show annotation(s) for a DICOM image 
test_fp = random.choice(image_fps_train)
image_annotations[test_fp]
# Out:
# [patientId    a83d65c1-4b19-452f-a486-4c34aee21c86
#  x                                             NaN
#  y                                             NaN
#  width                                         NaN
#  height                                        NaN
#  Target                                          0
#  Name: 17637, dtype: object]

# %%
# prepare the validation dataset
dataset_val = DetectorDataset(image_fps_val, image_annotations, ORIG_SIZE, ORIG_SIZE)
dataset_val.prepare()

# %%
# Load and display random samples and their bounding boxes
# Suggestion: Run this a few times to see different examples. 

image_id = random.choice(dataset_train.image_ids)
image_fp = dataset_train.image_reference(image_id)
image = dataset_train.load_image(image_id)
mask, class_ids = dataset_train.load_mask(image_id)

print(image.shape)

plt.figure(figsize=(10, 10))
plt.subplot(1, 2, 1)
plt.imshow(image[:, :, 0], cmap='gray')
plt.axis('off')

plt.subplot(1, 2, 2)
masked = np.zeros(image.shape[:2])
for i in range(mask.shape[2]):
    masked += image[:, :, 0] * mask[:, :, i]
plt.imshow(masked, cmap='gray')
plt.axis('off')

print(image_fp)
print(class_ids)
# Out:
# (1024, 1024, 3)
# /Pneumonia_Detection/stage_2_train_images/ac9d8fd5-2dad-41d8-a22c-31013afcdf48.dcm
# [0]

# %% [markdown]
# **Image Augmentation**

# %%
# Image augmentation 
augmentation = iaa.SomeOf((0, 1), [
    iaa.Fliplr(0.5),
    iaa.Affine(
        scale={"x": (0.8, 1.2), "y": (0.8, 1.2)},
        translate_percent={"x": (-0.2, 0.2), "y": (-0.2, 0.2)},
        rotate=(-25, 25),
        shear=(-8, 8)
    ),
    iaa.Multiply((0.9, 1.1))
])

# %%
model = modellib.MaskRCNN(mode='training', config=config, model_dir=MODEL_DIR)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
# %%time

# Train Mask-RCNN Model 
import warnings 
warnings.filterwarnings("ignore")
model.train(dataset_train, dataset_val, 
            learning_rate=config.LEARNING_RATE*5, 
            epochs=10,
            layers='all',
            augmentation=None)

history = model.keras_model.history.history
# Out:
# Starting at epoch 0. LR=0.005
#
# Checkpoint Path: /Pneumonia_Detection/working/pneumonia20190504T2142/mask_rcnn_pneumonia_{epoch:04d}.h5
# Selecting layers to train
# conv1                  (Conv2D)
# bn_conv1               (BatchNorm)
# res2a_branch2a         (Conv2D)
# bn2a_branch2a          (BatchNorm)
# res2a_branch2b         (Conv2D)
# bn2a_branch2b          (BatchNorm)
# res2a_branch2c         (Conv2D)
# res2a_branch1          (Conv2D)
# bn2a_branch2c          (BatchNorm)
# bn2a_branch1           (BatchNorm)
# res2b_branch2a         (Conv2D)
# bn2b_branch2a          (BatchNorm)
# res2b_branch2b         (Conv2D)
# bn2b_branch2b          (BatchNorm)
# res2b_branch2c         (Conv2D)
# bn2b_branch2c          (BatchNorm)
# res2c_branch2a         (Conv2D)
# bn2c_branch2a          (BatchNorm)
# res2c_branch2b         (Conv2D)
# bn2c_branch2b          (BatchNorm)
# res2c_branch2c         (Conv2D)
# bn2c_branch2c          (BatchNorm)
# res3a_branch2a         (Conv2D)
# bn3a_branch2a          (BatchNorm)
# res3a_branch2b         (Conv2D)
# bn3a_branch2b          (BatchNorm)
# res3a_branch2c         (Conv2D)
# res3a_branch1          (Conv2D)
# bn3a_branch2c          (BatchNorm)
# bn3a_branch1           (BatchNorm)
# res3b_branch2a         (Conv2D)
# bn3b_branch2a          (BatchNorm)
# res3b_branch2b         (Conv2D)
# bn3b_branch2b          (BatchNorm)
# res3b_branch2c         (Conv2D)
# bn3b_branch2c          (BatchNorm)
# res3c_branch2a         (Conv2D)
# bn3c_branch2a          (BatchNorm)
# res3c_branch2b         (Conv2D)
# bn3c_branch2b          (BatchNorm)
# res3c_branch2c         (Conv2D)
# bn3c_branch2c          (BatchNorm)
# res3d_branch2a         (Conv2D)
# bn3d_branch2a          (BatchNorm)
# res3d_branch2b         (Conv2D)
# bn3d_branch2b          (BatchNorm)
# res3d_branch2c         (Conv2D)
# bn3d_branch2c          (BatchNorm)
# res4a_branch2a         (Conv2D)
# bn4a_branch2a          (BatchNorm)
# res4a_branch2b         (Conv2D)
# bn4a_branch2b          (BatchNorm)
# res4a_branch2c         (Conv2D)
# res4a_branch1          (Conv2D)
# bn4a_branch2c          (BatchNorm)
# bn4a_branch1           (BatchNorm)
# res4b_branch2a         (Conv2D)
# bn4b_branch2a          (BatchNorm)
# res4b_branch2b         (Conv2D)
# bn4b_branch2b          (BatchNorm)
# res4b_branch2c         (Conv2D)
# bn4b_branch2c          (BatchNorm)
# res4c_branch2a         (Conv2D)
# bn4c_branch2a          (BatchNorm)
# res4c_branch2b         (Conv2D)
# bn4c_branch2b          (BatchNorm)
# res4c_branch2c         (Conv2D)
# bn4c_branch2c          (BatchNorm)
# res4d_branch2a         (Conv2D)
# bn4d_branch2a          (BatchNorm)
# res4d_branch2b         (Conv2D)
# bn4d_branch2b          (BatchNorm)
# res4d_branch2c         (Conv2D)
# bn4d_branch2c          (BatchNorm)
# res4e_branch2a         (Conv2D)
# bn4e_branch2a          (BatchNorm)
# res4e_branch2b         (Conv2D)
# bn4e_branch2b          (BatchNorm)
# res4e_branch2c         (Conv2D)
# bn4e_branch2c          (BatchNorm)
# res4f_branch2a         (Conv2D)
# bn4f_branch2a          (BatchNorm)
# res4f_branch2b         (Conv2D)
# bn4f_branch2b          (BatchNorm)
# res4f_branch2c         (Conv2D)
# bn4f_branch2c          (BatchNorm)
# res5a_branch2a         (Conv2D)
# bn5a_branch2a          (BatchNorm)
# res5a_branch2b         (Conv2D)
# bn5a_branch2b          (BatchNorm)
# res5a_branch2c         (Conv2D)
# res5a_branch1          (Conv2D)
# bn5a_branch2c          (BatchNorm)
# bn5a_branch1           (BatchNorm)
# res5b_branch2a         (Conv2D)
# bn5b_branch2a          (BatchNorm)
# res5b_branch2b         (Conv2D)
# bn5b_branch2b          (BatchNorm)
# res5b_branch2c         (Conv2D)
# bn5b_branch2c          (BatchNorm)
# res5c_branch2a         (Conv2D)
# bn5c_branch2a          (BatchNorm)
# res5c_branch2b         (Conv2D)
# bn5c_branch2b          (BatchNorm)
# res5c_branch2c         (Conv2D)
# bn5c_branch2c          (BatchNorm)
# fpn_c5p5               (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/10
# 150/150 [==============================] - 554s 4s/step - loss: 2.5433 - rpn_class_loss: 0.0717 - rpn_bbox_loss: 0.6779 - mrcnn_class_loss: 0.3644 - mrcnn_bbox_loss: 0.8832 - mrcnn_mask_loss: 0.5460 - val_loss: 1.9140 - val_rpn_class_loss: 0.0361 - val_rpn_bbox_loss: 0.4996 - val_mrcnn_class_loss: 0.2949 - val_mrcnn_bbox_loss: 0.6030 - val_mrcnn_mask_loss: 0.4803
# Epoch 2/10
# 150/150 [==============================] - 229s 2s/step - loss: 2.0079 - rpn_class_loss: 0.0319 - rpn_bbox_loss: 0.5393 - mrcnn_class_loss: 0.3368 - mrcnn_bbox_loss: 0.6157 - mrcnn_mask_loss: 0.4842 - val_loss: 2.1183 - val_rpn_class_loss: 0.0326 - val_rpn_bbox_loss: 0.5473 - val_mrcnn_class_loss: 0.3850 - val_mrcnn_bbox_loss: 0.6717 - val_mrcnn_mask_loss: 0.4818
# Epoch 3/10
# 150/150 [==============================] - 421s 3s/step - loss: 1.9445 - rpn_class_loss: 0.0310 - rpn_bbox_loss: 0.5421 - mrcnn_class_loss: 0.3149 - mrcnn_bbox_loss: 0.5893 - mrcnn_mask_loss: 0.4672 - val_loss: 2.1041 - val_rpn_class_loss: 0.0342 - val_rpn_bbox_loss: 0.7406 - val_mrcnn_class_loss: 0.2938 - val_mrcnn_bbox_loss: 0.5741 - val_mrcnn_mask_loss: 0.4613
# Epoch 4/10
# 150/150 [==============================] - 428s 3s/step - loss: 1.8654 - rpn_class_loss: 0.0294 - rpn_bbox_loss: 0.4975 - mrcnn_class_loss: 0.3103 - mrcnn_bbox_loss: 0.5687 - mrcnn_mask_loss: 0.4594 - val_loss: 1.8710 - val_rpn_class_loss: 0.0211 - val_rpn_bbox_loss: 0.5115 - val_mrcnn_class_loss: 0.2581 - val_mrcnn_bbox_loss: 0.5739 - val_mrcnn_mask_loss: 0.5063
# Epoch 5/10
# 150/150 [==============================] - 433s 3s/step - loss: 1.8964 - rpn_class_loss: 0.0246 - rpn_bbox_loss: 0.5428 - mrcnn_class_loss: 0.2983 - mrcnn_bbox_loss: 0.5707 - mrcnn_mask_loss: 0.4600 - val_loss: 1.8079 - val_rpn_class_loss: 0.0220 - val_rpn_bbox_loss: 0.4829 - val_mrcnn_class_loss: 0.3043 - val_mrcnn_bbox_loss: 0.5567 - val_mrcnn_mask_loss: 0.4421
# Epoch 6/10
# 150/150 [==============================] - 423s 3s/step - loss: 1.7870 - rpn_class_loss: 0.0230 - rpn_bbox_loss: 0.4969 - mrcnn_class_loss: 0.2844 - mrcnn_bbox_loss: 0.5486 - mrcnn_mask_loss: 0.4341 - val_loss: 1.9924 - val_rpn_class_loss: 0.0230 - val_rpn_bbox_loss: 0.6742 - val_mrcnn_class_loss: 0.2819 - val_mrcnn_bbox_loss: 0.5667 - val_mrcnn_mask_loss: 0.4466
# Epoch 7/10
# 150/150 [==============================] - 410s 3s/step - loss: 1.8166 - rpn_class_loss: 0.0219 - rpn_bbox_loss: 0.5290 - mrcnn_class_loss: 0.2792 - mrcnn_bbox_loss: 0.5462 - mrcnn_mask_loss: 0.4404 - val_loss: 1.7380 - val_rpn_class_loss: 0.0210 - val_rpn_bbox_loss: 0.4689 - val_mrcnn_class_loss: 0.2860 - val_mrcnn_bbox_loss: 0.5301 - val_mrcnn_mask_loss: 0.4319
# Epoch 8/10
# 150/150 [==============================] - 421s 3s/step - loss: 1.7758 - rpn_class_loss: 0.0226 - rpn_bbox_loss: 0.5074 - mrcnn_class_loss: 0.2850 - mrcnn_bbox_loss: 0.5265 - mrcnn_mask_loss: 0.4343 - val_loss: 1.6780 - val_rpn_class_loss: 0.0182 - val_rpn_bbox_loss: 0.4562 - val_mrcnn_class_loss: 0.2645 - val_mrcnn_bbox_loss: 0.5206 - val_mrcnn_mask_loss: 0.4186
# Epoch 9/10
# 150/150 [==============================] - 430s 3s/step - loss: 1.6778 - rpn_class_loss: 0.0170 - rpn_bbox_loss: 0.4250 - mrcnn_class_loss: 0.2870 - mrcnn_bbox_loss: 0.5219 - mrcnn_mask_loss: 0.4268 - val_loss: 1.7402 - val_rpn_class_loss: 0.0166 - val_rpn_bbox_loss: 0.4737 - val_mrcnn_class_loss: 0.2997 - val_mrcnn_bbox_loss: 0.5190 - val_mrcnn_mask_loss: 0.4312
# Epoch 10/10
# 150/150 [==============================] - 413s 3s/step - loss: 1.6948 - rpn_class_loss: 0.0186 - rpn_bbox_loss: 0.4637 - mrcnn_class_loss: 0.2789 - mrcnn_bbox_loss: 0.5058 - mrcnn_mask_loss: 0.4279 - val_loss: 1.9771 - val_rpn_class_loss: 0.0206 - val_rpn_bbox_loss: 0.6608 - val_mrcnn_class_loss: 0.3408 - val_mrcnn_bbox_loss: 0.5328 - val_mrcnn_mask_loss: 0.4220
# CPU times: user 21min 59s, sys: 56.3 s, total: 22min 55s
# Wall time: 1h 13min 34s

# %%
#Train with augmentation
# %%time
model.train(dataset_train, dataset_val,
            learning_rate=config.LEARNING_RATE*5,
            epochs=20,
            layers='all',
            augmentation=augmentation)

new_history = model.keras_model.history.history
for k in new_history: history[k] = history[k] + new_history[k]
# Out:
# Starting at epoch 10. LR=0.005
#
# Checkpoint Path: /Pneumonia_Detection/working/pneumonia20190504T2142/mask_rcnn_pneumonia_{epoch:04d}.h5
# Selecting layers to train
# conv1                  (Conv2D)
# bn_conv1               (BatchNorm)
# res2a_branch2a         (Conv2D)
# bn2a_branch2a          (BatchNorm)
# res2a_branch2b         (Conv2D)
# bn2a_branch2b          (BatchNorm)
# res2a_branch2c         (Conv2D)
# res2a_branch1          (Conv2D)
# bn2a_branch2c          (BatchNorm)
# bn2a_branch1           (BatchNorm)
# res2b_branch2a         (Conv2D)
# bn2b_branch2a          (BatchNorm)
# res2b_branch2b         (Conv2D)
# bn2b_branch2b          (BatchNorm)
# res2b_branch2c         (Conv2D)
# bn2b_branch2c          (BatchNorm)
# res2c_branch2a         (Conv2D)
# bn2c_branch2a          (BatchNorm)
# res2c_branch2b         (Conv2D)
# bn2c_branch2b          (BatchNorm)
# res2c_branch2c         (Conv2D)
# bn2c_branch2c          (BatchNorm)
# res3a_branch2a         (Conv2D)
# bn3a_branch2a          (BatchNorm)
# res3a_branch2b         (Conv2D)
# bn3a_branch2b          (BatchNorm)
# res3a_branch2c         (Conv2D)
# res3a_branch1          (Conv2D)
# bn3a_branch2c          (BatchNorm)
# bn3a_branch1           (BatchNorm)
# res3b_branch2a         (Conv2D)
# bn3b_branch2a          (BatchNorm)
# res3b_branch2b         (Conv2D)
# bn3b_branch2b          (BatchNorm)
# res3b_branch2c         (Conv2D)
# bn3b_branch2c          (BatchNorm)
# res3c_branch2a         (Conv2D)
# bn3c_branch2a          (BatchNorm)
# res3c_branch2b         (Conv2D)
# bn3c_branch2b          (BatchNorm)
# res3c_branch2c         (Conv2D)
# bn3c_branch2c          (BatchNorm)
# res3d_branch2a         (Conv2D)
# bn3d_branch2a          (BatchNorm)
# res3d_branch2b         (Conv2D)
# bn3d_branch2b          (BatchNorm)
# res3d_branch2c         (Conv2D)
# bn3d_branch2c          (BatchNorm)
# res4a_branch2a         (Conv2D)
# bn4a_branch2a          (BatchNorm)
# res4a_branch2b         (Conv2D)
# bn4a_branch2b          (BatchNorm)
# res4a_branch2c         (Conv2D)
# res4a_branch1          (Conv2D)
# bn4a_branch2c          (BatchNorm)
# bn4a_branch1           (BatchNorm)
# res4b_branch2a         (Conv2D)
# bn4b_branch2a          (BatchNorm)
# res4b_branch2b         (Conv2D)
# bn4b_branch2b          (BatchNorm)
# res4b_branch2c         (Conv2D)
# bn4b_branch2c          (BatchNorm)
# res4c_branch2a         (Conv2D)
# bn4c_branch2a          (BatchNorm)
# res4c_branch2b         (Conv2D)
# bn4c_branch2b          (BatchNorm)
# res4c_branch2c         (Conv2D)
# bn4c_branch2c          (BatchNorm)
# res4d_branch2a         (Conv2D)
# bn4d_branch2a          (BatchNorm)
# res4d_branch2b         (Conv2D)
# bn4d_branch2b          (BatchNorm)
# res4d_branch2c         (Conv2D)
# bn4d_branch2c          (BatchNorm)
# res4e_branch2a         (Conv2D)
# bn4e_branch2a          (BatchNorm)
# res4e_branch2b         (Conv2D)
# bn4e_branch2b          (BatchNorm)
# res4e_branch2c         (Conv2D)
# bn4e_branch2c          (BatchNorm)
# res4f_branch2a         (Conv2D)
# bn4f_branch2a          (BatchNorm)
# res4f_branch2b         (Conv2D)
# bn4f_branch2b          (BatchNorm)
# res4f_branch2c         (Conv2D)
# bn4f_branch2c          (BatchNorm)
# res5a_branch2a         (Conv2D)
# bn5a_branch2a          (BatchNorm)
# res5a_branch2b         (Conv2D)
# bn5a_branch2b          (BatchNorm)
# res5a_branch2c         (Conv2D)
# res5a_branch1          (Conv2D)
# bn5a_branch2c          (BatchNorm)
# bn5a_branch1           (BatchNorm)
# res5b_branch2a         (Conv2D)
# bn5b_branch2a          (BatchNorm)
# res5b_branch2b         (Conv2D)
# bn5b_branch2b          (BatchNorm)
# res5b_branch2c         (Conv2D)
# bn5b_branch2c          (BatchNorm)
# res5c_branch2a         (Conv2D)
# bn5c_branch2a          (BatchNorm)
# res5c_branch2b         (Conv2D)
# bn5c_branch2b          (BatchNorm)
# res5c_branch2c         (Conv2D)
# bn5c_branch2c          (BatchNorm)
# fpn_c5p5               (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# Epoch 11/20
# 150/150 [==============================] - 552s 4s/step - loss: 1.7268 - rpn_class_loss: 0.0195 - rpn_bbox_loss: 0.4640 - mrcnn_class_loss: 0.2864 - mrcnn_bbox_loss: 0.5186 - mrcnn_mask_loss: 0.4381 - val_loss: 1.6151 - val_rpn_class_loss: 0.0191 - val_rpn_bbox_loss: 0.4538 - val_mrcnn_class_loss: 0.2625 - val_mrcnn_bbox_loss: 0.4853 - val_mrcnn_mask_loss: 0.3943
# Epoch 12/20
# 150/150 [==============================] - 414s 3s/step - loss: 1.6911 - rpn_class_loss: 0.0181 - rpn_bbox_loss: 0.4395 - mrcnn_class_loss: 0.2742 - mrcnn_bbox_loss: 0.5222 - mrcnn_mask_loss: 0.4371 - val_loss: 1.7266 - val_rpn_class_loss: 0.0198 - val_rpn_bbox_loss: 0.4455 - val_mrcnn_class_loss: 0.3026 - val_mrcnn_bbox_loss: 0.5299 - val_mrcnn_mask_loss: 0.4288
# Epoch 13/20
# 150/150 [==============================] - 422s 3s/step - loss: 1.7300 - rpn_class_loss: 0.0194 - rpn_bbox_loss: 0.4903 - mrcnn_class_loss: 0.2734 - mrcnn_bbox_loss: 0.5120 - mrcnn_mask_loss: 0.4349 - val_loss: 1.7907 - val_rpn_class_loss: 0.0161 - val_rpn_bbox_loss: 0.5714 - val_mrcnn_class_loss: 0.3245 - val_mrcnn_bbox_loss: 0.4819 - val_mrcnn_mask_loss: 0.3969
# Epoch 14/20
# 150/150 [==============================] - 437s 3s/step - loss: 1.7608 - rpn_class_loss: 0.0203 - rpn_bbox_loss: 0.5039 - mrcnn_class_loss: 0.2812 - mrcnn_bbox_loss: 0.5189 - mrcnn_mask_loss: 0.4365 - val_loss: 1.6383 - val_rpn_class_loss: 0.0163 - val_rpn_bbox_loss: 0.4437 - val_mrcnn_class_loss: 0.2872 - val_mrcnn_bbox_loss: 0.4846 - val_mrcnn_mask_loss: 0.4065
# Epoch 15/20
# 150/150 [==============================] - 410s 3s/step - loss: 1.7205 - rpn_class_loss: 0.0174 - rpn_bbox_loss: 0.4710 - mrcnn_class_loss: 0.2786 - mrcnn_bbox_loss: 0.5182 - mrcnn_mask_loss: 0.4352 - val_loss: 1.8325 - val_rpn_class_loss: 0.0197 - val_rpn_bbox_loss: 0.6850 - val_mrcnn_class_loss: 0.1963 - val_mrcnn_bbox_loss: 0.4875 - val_mrcnn_mask_loss: 0.4440
# Epoch 16/20
# 150/150 [==============================] - 441s 3s/step - loss: 1.6834 - rpn_class_loss: 0.0177 - rpn_bbox_loss: 0.4626 - mrcnn_class_loss: 0.2764 - mrcnn_bbox_loss: 0.4984 - mrcnn_mask_loss: 0.4283 - val_loss: 1.7070 - val_rpn_class_loss: 0.0192 - val_rpn_bbox_loss: 0.4672 - val_mrcnn_class_loss: 0.2749 - val_mrcnn_bbox_loss: 0.5188 - val_mrcnn_mask_loss: 0.4269
# Epoch 17/20
# 150/150 [==============================] - 425s 3s/step - loss: 1.6747 - rpn_class_loss: 0.0172 - rpn_bbox_loss: 0.4611 - mrcnn_class_loss: 0.2818 - mrcnn_bbox_loss: 0.4902 - mrcnn_mask_loss: 0.4244 - val_loss: 1.5845 - val_rpn_class_loss: 0.0201 - val_rpn_bbox_loss: 0.4271 - val_mrcnn_class_loss: 0.2497 - val_mrcnn_bbox_loss: 0.4799 - val_mrcnn_mask_loss: 0.4078
# Epoch 18/20
# 150/150 [==============================] - 430s 3s/step - loss: 1.7044 - rpn_class_loss: 0.0193 - rpn_bbox_loss: 0.5064 - mrcnn_class_loss: 0.2726 - mrcnn_bbox_loss: 0.4806 - mrcnn_mask_loss: 0.4253 - val_loss: 1.6291 - val_rpn_class_loss: 0.0164 - val_rpn_bbox_loss: 0.3925 - val_mrcnn_class_loss: 0.2912 - val_mrcnn_bbox_loss: 0.5013 - val_mrcnn_mask_loss: 0.4277
# Epoch 19/20
# 150/150 [==============================] - 410s 3s/step - loss: 1.6094 - rpn_class_loss: 0.0160 - rpn_bbox_loss: 0.4250 - mrcnn_class_loss: 0.2658 - mrcnn_bbox_loss: 0.4827 - mrcnn_mask_loss: 0.4199 - val_loss: 1.7139 - val_rpn_class_loss: 0.0168 - val_rpn_bbox_loss: 0.5008 - val_mrcnn_class_loss: 0.2759 - val_mrcnn_bbox_loss: 0.4864 - val_mrcnn_mask_loss: 0.4339
# Epoch 20/20
# 150/150 [==============================] - 420s 3s/step - loss: 1.6582 - rpn_class_loss: 0.0170 - rpn_bbox_loss: 0.4479 - mrcnn_class_loss: 0.2977 - mrcnn_bbox_loss: 0.4799 - mrcnn_mask_loss: 0.4158 - val_loss: 1.6334 - val_rpn_class_loss: 0.0151 - val_rpn_bbox_loss: 0.4654 - val_mrcnn_class_loss: 0.2860 - val_mrcnn_bbox_loss: 0.4637 - val_mrcnn_mask_loss: 0.4031
# CPU times: user 20min, sys: 53.4 s, total: 20min 53s
# Wall time: 1h 13min 28s

# %%
#Train with a lower learning rate
# %%time
model.train(dataset_train, dataset_val,
            learning_rate=config.LEARNING_RATE,
            epochs=30,
            layers='all',
            augmentation=augmentation)

new_history = model.keras_model.history.history
for k in new_history: history[k] = history[k] + new_history[k]
# Out:
# Starting at epoch 20. LR=0.001
#
# Checkpoint Path: /Pneumonia_Detection/working/pneumonia20190504T2142/mask_rcnn_pneumonia_{epoch:04d}.h5
# Selecting layers to train
# conv1                  (Conv2D)
# bn_conv1               (BatchNorm)
# res2a_branch2a         (Conv2D)
# bn2a_branch2a          (BatchNorm)
# res2a_branch2b         (Conv2D)
# bn2a_branch2b          (BatchNorm)
# res2a_branch2c         (Conv2D)
# res2a_branch1          (Conv2D)
# bn2a_branch2c          (BatchNorm)
# bn2a_branch1           (BatchNorm)
# res2b_branch2a         (Conv2D)
# bn2b_branch2a          (BatchNorm)
# res2b_branch2b         (Conv2D)
# bn2b_branch2b          (BatchNorm)
# res2b_branch2c         (Conv2D)
# bn2b_branch2c          (BatchNorm)
# res2c_branch2a         (Conv2D)
# bn2c_branch2a          (BatchNorm)
# res2c_branch2b         (Conv2D)
# bn2c_branch2b          (BatchNorm)
# res2c_branch2c         (Conv2D)
# bn2c_branch2c          (BatchNorm)
# res3a_branch2a         (Conv2D)
# bn3a_branch2a          (BatchNorm)
# res3a_branch2b         (Conv2D)
# bn3a_branch2b          (BatchNorm)
# res3a_branch2c         (Conv2D)
# res3a_branch1          (Conv2D)
# bn3a_branch2c          (BatchNorm)
# bn3a_branch1           (BatchNorm)
# res3b_branch2a         (Conv2D)
# bn3b_branch2a          (BatchNorm)
# res3b_branch2b         (Conv2D)
# bn3b_branch2b          (BatchNorm)
# res3b_branch2c         (Conv2D)
# bn3b_branch2c          (BatchNorm)
# res3c_branch2a         (Conv2D)
# bn3c_branch2a          (BatchNorm)
# res3c_branch2b         (Conv2D)
# bn3c_branch2b          (BatchNorm)
# res3c_branch2c         (Conv2D)
# bn3c_branch2c          (BatchNorm)
# res3d_branch2a         (Conv2D)
# bn3d_branch2a          (BatchNorm)
# res3d_branch2b         (Conv2D)
# bn3d_branch2b          (BatchNorm)
# res3d_branch2c         (Conv2D)
# bn3d_branch2c          (BatchNorm)
# res4a_branch2a         (Conv2D)
# bn4a_branch2a          (BatchNorm)
# res4a_branch2b         (Conv2D)
# bn4a_branch2b          (BatchNorm)
# res4a_branch2c         (Conv2D)
# res4a_branch1          (Conv2D)
# bn4a_branch2c          (BatchNorm)
# bn4a_branch1           (BatchNorm)
# res4b_branch2a         (Conv2D)
# bn4b_branch2a          (BatchNorm)
# res4b_branch2b         (Conv2D)
# bn4b_branch2b          (BatchNorm)
# res4b_branch2c         (Conv2D)
# bn4b_branch2c          (BatchNorm)
# res4c_branch2a         (Conv2D)
# bn4c_branch2a          (BatchNorm)
# res4c_branch2b         (Conv2D)
# bn4c_branch2b          (BatchNorm)
# res4c_branch2c         (Conv2D)
# bn4c_branch2c          (BatchNorm)
# res4d_branch2a         (Conv2D)
# bn4d_branch2a          (BatchNorm)
# res4d_branch2b         (Conv2D)
# bn4d_branch2b          (BatchNorm)
# res4d_branch2c         (Conv2D)
# bn4d_branch2c          (BatchNorm)
# res4e_branch2a         (Conv2D)
# bn4e_branch2a          (BatchNorm)
# res4e_branch2b         (Conv2D)
# bn4e_branch2b          (BatchNorm)
# res4e_branch2c         (Conv2D)
# bn4e_branch2c          (BatchNorm)
# res4f_branch2a         (Conv2D)
# bn4f_branch2a          (BatchNorm)
# res4f_branch2b         (Conv2D)
# bn4f_branch2b          (BatchNorm)
# res4f_branch2c         (Conv2D)
# bn4f_branch2c          (BatchNorm)
# res5a_branch2a         (Conv2D)
# bn5a_branch2a          (BatchNorm)
# res5a_branch2b         (Conv2D)
# bn5a_branch2b          (BatchNorm)
# res5a_branch2c         (Conv2D)
# res5a_branch1          (Conv2D)
# bn5a_branch2c          (BatchNorm)
# bn5a_branch1           (BatchNorm)
# res5b_branch2a         (Conv2D)
# bn5b_branch2a          (BatchNorm)
# res5b_branch2b         (Conv2D)
# bn5b_branch2b          (BatchNorm)
# res5b_branch2c         (Conv2D)
# bn5b_branch2c          (BatchNorm)
# res5c_branch2a         (Conv2D)
# bn5c_branch2a          (BatchNorm)
# res5c_branch2b         (Conv2D)
# bn5c_branch2b          (BatchNorm)
# res5c_branch2c         (Conv2D)
# bn5c_branch2c          (BatchNorm)
# fpn_c5p5               (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# Epoch 21/30
# 150/150 [==============================] - 553s 4s/step - loss: 1.5548 - rpn_class_loss: 0.0159 - rpn_bbox_loss: 0.4135 - mrcnn_class_loss: 0.2571 - mrcnn_bbox_loss: 0.4569 - mrcnn_mask_loss: 0.4114 - val_loss: 1.4549 - val_rpn_class_loss: 0.0138 - val_rpn_bbox_loss: 0.3927 - val_mrcnn_class_loss: 0.2398 - val_mrcnn_bbox_loss: 0.4243 - val_mrcnn_mask_loss: 0.3844
# Epoch 22/30
# 150/150 [==============================] - 394s 3s/step - loss: 1.5034 - rpn_class_loss: 0.0143 - rpn_bbox_loss: 0.3960 - mrcnn_class_loss: 0.2422 - mrcnn_bbox_loss: 0.4454 - mrcnn_mask_loss: 0.4055 - val_loss: 1.4916 - val_rpn_class_loss: 0.0150 - val_rpn_bbox_loss: 0.4109 - val_mrcnn_class_loss: 0.2292 - val_mrcnn_bbox_loss: 0.4435 - val_mrcnn_mask_loss: 0.3929
# Epoch 23/30
# 150/150 [==============================] - 418s 3s/step - loss: 1.5408 - rpn_class_loss: 0.0151 - rpn_bbox_loss: 0.4179 - mrcnn_class_loss: 0.2470 - mrcnn_bbox_loss: 0.4511 - mrcnn_mask_loss: 0.4097 - val_loss: 1.5522 - val_rpn_class_loss: 0.0147 - val_rpn_bbox_loss: 0.4831 - val_mrcnn_class_loss: 0.2427 - val_mrcnn_bbox_loss: 0.4285 - val_mrcnn_mask_loss: 0.3832
# Epoch 24/30
# 150/150 [==============================] - 435s 3s/step - loss: 1.5176 - rpn_class_loss: 0.0154 - rpn_bbox_loss: 0.4134 - mrcnn_class_loss: 0.2412 - mrcnn_bbox_loss: 0.4413 - mrcnn_mask_loss: 0.4063 - val_loss: 1.4303 - val_rpn_class_loss: 0.0128 - val_rpn_bbox_loss: 0.3922 - val_mrcnn_class_loss: 0.2188 - val_mrcnn_bbox_loss: 0.4231 - val_mrcnn_mask_loss: 0.3834
# Epoch 25/30
# 150/150 [==============================] - 412s 3s/step - loss: 1.4899 - rpn_class_loss: 0.0138 - rpn_bbox_loss: 0.3884 - mrcnn_class_loss: 0.2374 - mrcnn_bbox_loss: 0.4443 - mrcnn_mask_loss: 0.4059 - val_loss: 1.4338 - val_rpn_class_loss: 0.0128 - val_rpn_bbox_loss: 0.3933 - val_mrcnn_class_loss: 0.2283 - val_mrcnn_bbox_loss: 0.4160 - val_mrcnn_mask_loss: 0.3834
# Epoch 26/30
# 150/150 [==============================] - 420s 3s/step - loss: 1.4534 - rpn_class_loss: 0.0140 - rpn_bbox_loss: 0.3828 - mrcnn_class_loss: 0.2332 - mrcnn_bbox_loss: 0.4259 - mrcnn_mask_loss: 0.3976 - val_loss: 1.5080 - val_rpn_class_loss: 0.0145 - val_rpn_bbox_loss: 0.4259 - val_mrcnn_class_loss: 0.2218 - val_mrcnn_bbox_loss: 0.4481 - val_mrcnn_mask_loss: 0.3976
# Epoch 27/30
# 150/150 [==============================] - 412s 3s/step - loss: 1.4636 - rpn_class_loss: 0.0133 - rpn_bbox_loss: 0.3924 - mrcnn_class_loss: 0.2348 - mrcnn_bbox_loss: 0.4236 - mrcnn_mask_loss: 0.3995 - val_loss: 1.4534 - val_rpn_class_loss: 0.0140 - val_rpn_bbox_loss: 0.3804 - val_mrcnn_class_loss: 0.2398 - val_mrcnn_bbox_loss: 0.4239 - val_mrcnn_mask_loss: 0.3952
# Epoch 28/30
# 150/150 [==============================] - 415s 3s/step - loss: 1.4913 - rpn_class_loss: 0.0143 - rpn_bbox_loss: 0.3952 - mrcnn_class_loss: 0.2521 - mrcnn_bbox_loss: 0.4274 - mrcnn_mask_loss: 0.4022 - val_loss: 1.4485 - val_rpn_class_loss: 0.0130 - val_rpn_bbox_loss: 0.3875 - val_mrcnn_class_loss: 0.2344 - val_mrcnn_bbox_loss: 0.4259 - val_mrcnn_mask_loss: 0.3877
# Epoch 29/30
# 150/150 [==============================] - 429s 3s/step - loss: 1.4432 - rpn_class_loss: 0.0127 - rpn_bbox_loss: 0.3717 - mrcnn_class_loss: 0.2340 - mrcnn_bbox_loss: 0.4263 - mrcnn_mask_loss: 0.3984 - val_loss: 1.4729 - val_rpn_class_loss: 0.0127 - val_rpn_bbox_loss: 0.4119 - val_mrcnn_class_loss: 0.2535 - val_mrcnn_bbox_loss: 0.4078 - val_mrcnn_mask_loss: 0.3868
# Epoch 30/30
# 150/150 [==============================] - 413s 3s/step - loss: 1.4277 - rpn_class_loss: 0.0132 - rpn_bbox_loss: 0.3401 - mrcnn_class_loss: 0.2517 - mrcnn_bbox_loss: 0.4219 - mrcnn_mask_loss: 0.4008 - val_loss: 1.5332 - val_rpn_class_loss: 0.0134 - val_rpn_bbox_loss: 0.4978 - val_mrcnn_class_loss: 0.2145 - val_mrcnn_bbox_loss: 0.4179 - val_mrcnn_mask_loss: 0.3896
# CPU times: user 17min 58s, sys: 53.5 s, total: 18min 52s
# Wall time: 1h 12min 35s

# %%
epochs = range(1,len(next(iter(history.values())))+1)
log1 = pd.DataFrame(history, index=epochs)

# %%
plt.figure(figsize=(17,5))

plt.subplot(131)
plt.plot(epochs, history["loss"], label="Train loss")
plt.plot(epochs, history["val_loss"], label="Valid loss")
plt.legend()
plt.subplot(132)
plt.plot(epochs, history["mrcnn_class_loss"], label="Train class ce")
plt.plot(epochs, history["val_mrcnn_class_loss"], label="Valid class ce")
plt.legend()
plt.subplot(133)
plt.plot(epochs, history["mrcnn_bbox_loss"], label="Train box loss")
plt.plot(epochs, history["val_mrcnn_bbox_loss"], label="Valid box loss")
plt.legend()

plt.show()

# %%
#Find the best epoch
best_epoch = np.argmin(history["val_loss"])
print("Best Epoch:", best_epoch + 1, history["val_loss"][best_epoch])
# Out:
# Best Epoch: 24 1.430309729576111

# %%
# select trained model 
dir_names = next(os.walk(model.model_dir))[1]
key = config.NAME.lower()
dir_names = filter(lambda f: f.startswith(key), dir_names)
dir_names = sorted(dir_names)

if not dir_names:
    import errno
    raise FileNotFoundError(
        errno.ENOENT,
        "Could not find model directory under {}".format(self.model_dir))
    
fps = []
# Pick last directory
for d in dir_names: 
    dir_name = os.path.join(model.model_dir, d)
    # Find the last checkpoint
    checkpoints = next(os.walk(dir_name))[2]
    checkpoints = filter(lambda f: f.startswith("mask_rcnn"), checkpoints)
    checkpoints = sorted(checkpoints)
    if not checkpoints:
        print('No weight files in {}'.format(dir_name))
    else:
        checkpoint = os.path.join(dir_name, checkpoints[best_epoch])
        fps.append(checkpoint)

model_path = sorted(fps)[-1]
print('Found model {}'.format(model_path))
# Out:
# Found model /Pneumonia_Detection/working/pneumonia20190504T2142/mask_rcnn_pneumonia_0024.h5

# %%
class InferenceConfig(DetectorConfig):
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1

inference_config = InferenceConfig()

# Recreate the model in inference mode
model = modellib.MaskRCNN(mode='inference', 
                          config=inference_config,
                          model_dir=ROOT_DIR)

# Load trained weights (fill in path to trained weights here)
assert model_path != "", "Provide path to trained weights"
print("Loading weights from ", model_path)
model.load_weights(model_path, by_name=True)
# Out:
# WARNING:tensorflow:From /Pneumonia_Detection/Mask_RCNN/mrcnn/model.py:772: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Loading weights from  /Pneumonia_Detection/working/pneumonia20190504T2142/mask_rcnn_pneumonia_0024.h5
# Re-starting from epoch 24

# %%
# set color for class
def get_colors_for_class_ids(class_ids):
    colors = []
    for class_id in class_ids:
        if class_id == 1:
            colors.append((.941, .204, .204))
    return colors

# %%
# Show few example of ground truth vs. predictions on the validation dataset 
dataset = dataset_val
fig = plt.figure(figsize=(10, 30))

for i in range(4):

    image_id = random.choice(dataset.image_ids)
    
    original_image, image_meta, gt_class_id, gt_bbox, gt_mask =\
        modellib.load_image_gt(dataset_val, inference_config, 
                               image_id, use_mini_mask=False)
        
    plt.subplot(6, 2, 2*i + 1)
    visualize.display_instances(original_image, gt_bbox, gt_mask, gt_class_id, 
                                dataset.class_names,
                                colors=get_colors_for_class_ids(gt_class_id), ax=fig.axes[-1])
    
    plt.subplot(6, 2, 2*i + 2)
    results = model.detect([original_image]) #, verbose=1)
    r = results[0]
    visualize.display_instances(original_image, r['rois'], r['masks'], r['class_ids'], 
                                dataset.class_names, r['scores'], 
                                colors=get_colors_for_class_ids(r['class_ids']), ax=fig.axes[-1])
# Out:
# *** No instances to display ***
#
#
# *** No instances to display ***
#
#
# *** No instances to display ***

# %%
# Get filenames of test dataset DICOM images
test_image_fps = get_dicom_fps(test_dicom_dir)

# %%
# Make predictions on test images, write out sample submission
def predict(image_fps, filepath='submission.csv', min_conf=0.95):
    # assume square image
    resize_factor = ORIG_SIZE / config.IMAGE_SHAPE[0]
    #resize_factor = ORIG_SIZE
    with open(filepath, 'w') as file:
        file.write("patientId,PredictionString\n")

        for image_id in tqdm(image_fps):
            ds = pydicom.read_file(image_id)
            image = ds.pixel_array
            # If grayscale. Convert to RGB for consistency.
            if len(image.shape) != 3 or image.shape[2] != 3:
                image = np.stack((image,) * 3, -1)
            image, window, scale, padding, crop = utils.resize_image(
                image,
                min_dim=config.IMAGE_MIN_DIM,
                min_scale=config.IMAGE_MIN_SCALE,
                max_dim=config.IMAGE_MAX_DIM,
                mode=config.IMAGE_RESIZE_MODE)

            patient_id = os.path.splitext(os.path.basename(image_id))[0]

            results = model.detect([image])
            r = results[0]

            out_str = ""
            out_str += patient_id
            out_str += ","
            assert( len(r['rois']) == len(r['class_ids']) == len(r['scores']) )
            if len(r['rois']) == 0:
                pass
            else:
                num_instances = len(r['rois'])

                for i in range(num_instances):
                    if r['scores'][i] > min_conf:
                        out_str += ' '
                        out_str += str(round(r['scores'][i], 2))
                        out_str += ' '

                        # x1, y1, width, height
                        x1 = r['rois'][i][1]
                        y1 = r['rois'][i][0]
                        width = r['rois'][i][3] - x1
                        height = r['rois'][i][2] - y1
                        bboxes_str = "{} {} {} {}".format(x1*resize_factor, y1*resize_factor, \
                                                           width*resize_factor, height*resize_factor)
                        out_str += bboxes_str

            file.write(out_str+"\n")

# %%
submission_fp = os.path.join(ROOT_DIR, 'submission.csv')
predict(test_image_fps, filepath=submission_fp)
print(submission_fp)
# Out:
# 100%|██████████| 3000/3000 [06:41<00:00,  7.77it/s]
# /Pneumonia_Detection/submission.csv

# %%
output = pd.read_csv(submission_fp)
output.head(60)
# Out:
#                                patientId  \
# 0   0357ec4c-be16-4c0c-a0e9-7fa38df30c84
# 1   233fd25f-9705-4e1b-befe-a25f5ed68c82
# 2   1ef27e91-b8c6-4f53-bb83-1bb7f0b9b933
# 3   285b5785-cab1-4713-b345-51dc7e5bde93
# 4   28278841-6318-4065-a93d-47b80ee8482a
# 5   13b9ae14-0b10-4323-aa31-b6c0b4f5e497
# 6   2cdd0947-ec15-4210-9abe-3fd3d6cf4729
# 7   2853a995-743e-43d8-9ea4-068ffc6bf420
# 8   2f6abbc6-0f2a-4951-9eae-10b784fd74b7
# 9   1cb71dda-47f2-44e0-ad42-2737ec3f43b6
# 10  0385d49e-7642-445a-bffc-28915cee0056
# 11  200035d6-f2fa-4281-b1be-781fa95e015e
# 12  2b62bfe4-8fcb-4666-a3c9-44aa6fa0d9c2
# 13  1ede5f6e-d575-4e09-9381-5a3da66540fd
# 14  13f76876-328a-4b88-ac58-a3c1fe15b3b2
# 15  2c57f3c2-af21-40dd-a7b0-16b5c04c419d
# 16  139b2baa-9c95-4ec9-8d91-1642144834d6
# 17  23a26c71-73e0-4cb2-b2ae-661a04c696dc
# 18  1a6741c4-d9b2-42d8-a442-002e60565e1e
# 19  05b2cc6d-8a25-47c8-a191-bbaaadf0bf64
# 20  2463ccff-9423-4c71-9eab-d23b2aeccdb2
# 21  0f4cce56-c99d-47db-b9f6-2c95f4555c7d
# 22  0123ddde-aa60-4364-a3c5-2aed75bba3dd
# 23  107cde4d-12de-42ce-ab5b-abd6a2c55c2b
# 24  311db5d7-eec8-456e-b6cc-5c078dce0bed
# 25  1429fe63-8d51-4017-9d9b-c7030da74621
# 26  237e9d10-fbb2-4dd0-a808-999a37cee304
# 27  104f01b9-7f61-49b4-836c-de1cef558910
# 28  2efd4438-6385-4c97-8869-82c83e739756
# 29  24b01fee-8258-4952-9b06-75a5e245f8e7
# 30  0ddc2515-b699-4b06-9cce-f2b7c3602449
# 31  2e4e79b7-004b-436b-81fe-0fe90f29fb65
# 32  2cef7047-89ac-4a3b-84c5-9641933c6bd5
# 33  0f418437-6440-4145-a7f7-b254a91f5240
# 34  24e408ee-ffab-4bc2-b82e-356d87e2b20d
# 35  011949a0-b52b-424d-b78f-afc3926ef2de
# 36  008efe9c-946b-4f43-ae07-942f8d73dcc1
# 37  2e1a4630-2cd8-4dae-b867-6628b2aa1939
# 38  13e17582-bd0c-41e4-afd7-af95d6c1a29e
# 39  1b10797b-9f2e-443f-b279-da2c1d7c5801
# 40  2e4e7205-8ffc-4b26-bf0d-8e5864b7238c
# 41  1503ef72-d4a4-44c0-83c8-d35f449fe53a
# 42  2c5b8ef5-ebed-4b39-91e0-d59ec302503a
# 43  04b196dc-81cf-45f4-9180-e6766614599f
# 44  14aac35d-3205-4861-8bc5-eb37d90f8298
# 45  04269ea9-d43c-4f01-a72a-d340fb49ff27
# 46  0417f292-9baa-47d3-a4a6-9cab52844cec
# 47  268116a6-2304-4316-b5b3-3073fc5467b1
# 48  1ae8be61-41d5-4197-b733-21701ec45a6f
# 49  19fb178c-3ca7-4a72-bef9-8ba442535dff
# 50  21ea97d1-c6f8-460a-8487-8530b4fcef02
# 51  00f376d8-24a0-45b4-a2fa-fef47e2f9f9e
# 52  c1e5e19a-4aa3-437f-839c-a90e30e30a5f
# 53  1fc7fea2-7b2e-4fe0-a74f-6f7e6ba86e4f
# 54  0ef5e498-d7e4-438e-a957-3acb44e05372
# 55  0eb34bbd-a1f9-4006-96e2-0ebcad6af512
# 56  13e4e6e6-faa2-4bbc-8e1e-610623de994e
# 57  0d2e6cd3-a646-4cad-942b-59fcf226fc27
# 58  2d3cfc9f-d0b7-4c6b-882e-cdde29b92bcf
# 59  0452d6c6-4693-4ade-8b20-46e09c719ada
#
#                                      PredictionString
# 0                        0.97 156.0 528.0 232.0 268.0
# 1                                                 NaN
# 2                                                 NaN
# 3    0.98 188.0 480.0 228.0 208.0 0.98 612.0 284.0...
# 4                        0.98 612.0 468.0 212.0 280.0
# 5                        0.99 176.0 404.0 240.0 356.0
# 6                        0.98 620.0 420.0 256.0 252.0
# 7                        0.97 596.0 532.0 248.0 192.0
# 8                                                 NaN
# 9    0.98 180.0 512.0 272.0 212.0 0.97 632.0 476.0...
# 10                                                NaN
# 11                       0.97 228.0 436.0 256.0 260.0
# 12                       0.98 216.0 412.0 192.0 228.0
# 13                       0.98 204.0 388.0 228.0 244.0
# 14                       0.98 188.0 472.0 252.0 300.0
# 15                       0.96 288.0 584.0 160.0 164.0
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                       0.97 200.0 348.0 244.0 360.0
# 22                       0.97 240.0 376.0 212.0 388.0
# 23                       0.96 176.0 488.0 248.0 168.0
# 24   0.97 492.0 284.0 268.0 500.0 0.96 108.0 260.0...
# 25   0.97 188.0 540.0 228.0 372.0 0.96 624.0 520.0...
# 26                       0.96 568.0 304.0 252.0 312.0
# 27                       0.97 208.0 488.0 220.0 184.0
# 28   0.99 580.0 420.0 220.0 296.0 0.97 232.0 452.0...
# 29                       0.96 600.0 548.0 264.0 308.0
# 30                       0.96 248.0 276.0 212.0 332.0
# 31                       0.96 284.0 476.0 180.0 284.0
# 32   0.98 244.0 484.0 204.0 280.0 0.96 652.0 296.0...
# 33                       0.96 612.0 580.0 252.0 208.0
# 34   0.97 624.0 240.0 280.0 544.0 0.95 252.0 388.0...
# 35   0.98 588.0 460.0 232.0 212.0 0.97 192.0 348.0...
# 36   0.97 112.0 384.0 272.0 360.0 0.96 576.0 400.0...
# 37                                                NaN
# 38                                                NaN
# 39                       0.97 200.0 504.0 272.0 244.0
# 40                       0.96 288.0 192.0 208.0 488.0
# 41                       0.98 140.0 492.0 228.0 200.0
# 42   0.98 540.0 488.0 260.0 168.0 0.97 160.0 396.0...
# 43   0.98 196.0 488.0 224.0 256.0 0.95 556.0 520.0...
# 44                       0.98 228.0 480.0 184.0 352.0
# 45                                                NaN
# 46                       0.98 208.0 400.0 188.0 256.0
# 47                       0.95 132.0 568.0 268.0 212.0
# 48   0.99 148.0 268.0 208.0 504.0 0.97 496.0 352.0...
# 49                       0.96 224.0 480.0 248.0 236.0
# 50                                                NaN
# 51   0.99 264.0 448.0 196.0 372.0 0.96 612.0 456.0...
# 52                                                NaN
# 53                                                NaN
# 54                                                NaN
# 55                       0.96 236.0 632.0 200.0 144.0
# 56                       0.96 216.0 352.0 204.0 324.0
# 57                       0.98 224.0 468.0 176.0 312.0
# 58                                                NaN
# 59                                                NaN

# %%
files.download(submission_fp)
