# %% [markdown]
# <a href="https://colab.research.google.com/github/v-patel18/Data-Mining_Final-Project/blob/master/Pneumonia_Detection_Challenge_Trial_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Install necessary packages
# !pip3 install -q pydicom 
# !pip3 install -q tqdm 
# !pip3 install -q imgaug 

#Use Kaggle API to download data
# !pip3 install -q kaggle

#Import necessary libraries
import os 
import sys

import random
import math
import numpy as np
import cv2
import matplotlib.pyplot as plt
import json
import pydicom
from imgaug import augmenters as iaa
from tqdm import tqdm
import pandas as pd 
import glob
# Out:
#      |████████████████████████████████| 7.0MB 2.6MB/s

# %%
# Use Kaggle credentials to download data
os.environ['KAGGLE_USERNAME']="vasvip"
os.environ['KAGGLE_KEY']="39829c7c09776b1754776f543a2459d1"

# Root directory of the project
ROOT_DIR = os.path.abspath('/Pneumonia_Detection')

# Directory to save logs and trained model
MODEL_DIR = os.path.join(ROOT_DIR, 'working')

if not os.path.exists(ROOT_DIR):
    os.makedirs(ROOT_DIR)
os.chdir(ROOT_DIR)

#Download dataset for the competition
# !kaggle competitions download -c rsna-pneumonia-detection-challenge
# Out:
# Downloading stage_2_detailed_class_info.csv.zip to /Pneumonia_Detection
#   0% 0.00/583k [00:00<?, ?B/s]
# 100% 583k/583k [00:00<00:00, 77.9MB/s]
# Downloading stage_2_sample_submission.csv to /Pneumonia_Detection
#   0% 0.00/155k [00:00<?, ?B/s]
# 100% 155k/155k [00:00<00:00, 48.8MB/s]
# Downloading stage_2_train_labels.csv.zip to /Pneumonia_Detection
#   0% 0.00/661k [00:00<?, ?B/s]
# 100% 661k/661k [00:00<00:00, 92.4MB/s]
# Downloading stage_2_test_images.zip to /Pneumonia_Detection
#  97% 364M/377M [00:02<00:00, 194MB/s]
# 100% 377M/377M [00:02<00:00, 185MB/s]
# Downloading stage_2_train_images.zip to /Pneumonia_Detection
# 100% 3.29G/3.29G [00:22<00:00, 200MB/s]
# 100% 3.29G/3.29G [00:22<00:00, 154MB/s]
# Downloading GCP%20Credits%20Request%20Link%20-%20RSNA.txt to /Pneumonia_Detection
#   0% 0.00/55.0 [00:00<?, ?B/s]
# 100% 55.0/55.0 [00:00<00:00, 56.3kB/s]

# %%
# Unzip the downloaded files
# !unzip -q -o stage_2_test_images.zip -d stage_2_test_images
# !unzip -q -o stage_2_train_images.zip -d stage_2_train_images
# !unzip -q -o stage_2_train_labels.csv.zip

# %% [markdown]
# **Install Matterport's Mask-RCNN implementation from GitHub**

# %%
os.chdir(ROOT_DIR)
# !git clone https://github.com/matterport/Mask_RCNN.git
os.chdir('Mask_RCNN')
# !python setup.py -q install

# Import Mask RCNN
sys.path.append(os.path.join(ROOT_DIR, 'Mask_RCNN'))  # To find local version of the library
from mrcnn.config import Config
from mrcnn import utils
import mrcnn.model as modellib
from mrcnn import visualize
from mrcnn.model import log
# Out:
# Cloning into 'Mask_RCNN'...
# remote: Enumerating objects: 956, done.
# remote: Total 956 (delta 0), reused 0 (delta 0), pack-reused 956
# Receiving objects: 100% (956/956), 119.70 MiB | 39.32 MiB/s, done.
# Resolving deltas: 100% (555/555), done.
# WARNING:root:Fail load requirements file, so using default ones.
# zip_safe flag not set; analyzing archive contents...
# Using TensorFlow backend.

# %%
train_dicom_dir = os.path.join(ROOT_DIR, 'stage_2_train_images')
test_dicom_dir = os.path.join(ROOT_DIR, 'stage_2_test_images')

# %%
def get_dicom_fps(dicom_dir):
    dicom_fps = glob.glob(dicom_dir+'/'+'*.dcm')
    return list(set(dicom_fps))

def parse_dataset(dicom_dir, anns): 
    image_fps = get_dicom_fps(dicom_dir)
    image_annotations = {fp: [] for fp in image_fps}
    for index, row in anns.iterrows(): 
        fp = os.path.join(dicom_dir, row['patientId']+'.dcm')
        image_annotations[fp].append(row)
    return image_fps, image_annotations

# %%
class DetectorConfig(Config):
    """Configuration for training pneumonia detection on the RSNA pneumonia dataset.
    Overrides values in the base Config class.
    """
    
    # Give the configuration a recognizable name  
    NAME = 'pneumonia'
    
    # Train on 1 GPU and 8 images per GPU. We can put multiple images on each
    # GPU because the images are small. Batch size is 8 (GPUs * images/GPU).
    GPU_COUNT = 1
    IMAGES_PER_GPU = 8 
    
    BACKBONE = 'resnet50'
    
    NUM_CLASSES = 2  # background + 1 pneumonia classes
    
    # Use small images for faster training. Set the limits of the small side
    # the large side, and that determines the image shape.
    IMAGE_MIN_DIM = 256
    IMAGE_MAX_DIM = 256
    
    RPN_ANCHOR_SCALES = (16, 32, 64, 128)
    
    TRAIN_ROIS_PER_IMAGE = 32
    
    MAX_GT_INSTANCES = 3
    
    DETECTION_MAX_INSTANCES = 3
    DETECTION_MIN_CONFIDENCE = 0.8
    DETECTION_NMS_THRESHOLD = 0.05
    
    RPN_TRAIN_ANCHORS_PER_IMAGE = 256
    STEPS_PER_EPOCH = 150 
    TOP_DOWN_PYRAMID_SIZE = 256
    
    
config = DetectorConfig()
config.display()
# Out:
# Configurations:
# BACKBONE                       resnet50
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     8
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        3
# DETECTION_MIN_CONFIDENCE       0.8
# DETECTION_NMS_THRESHOLD        0.05
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 8
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  256
# IMAGE_META_SIZE                14
# IMAGE_MIN_DIM                  256
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [256 256   3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               3
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           pneumonia
# NUM_CLASSES                    2
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# PRE_NMS_LIMIT                  6000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (16, 32, 64, 128)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                150
# TOP_DOWN_PYRAMID_SIZE          256
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           32
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               50
# WEIGHT_DECAY                   0.0001

# %%
class DetectorDataset(utils.Dataset):
    """Dataset class for training pneumonia detection on the RSNA pneumonia dataset.
    """

    def __init__(self, image_fps, image_annotations, orig_height, orig_width):
        super().__init__(self)
        
        # Add classes
        self.add_class('pneumonia', 1, 'Lung Opacity')
   
        # add images 
        for i, fp in enumerate(image_fps):
            annotations = image_annotations[fp]
            self.add_image('pneumonia', image_id=i, path=fp, 
                           annotations=annotations, orig_height=orig_height, orig_width=orig_width)
            
    def image_reference(self, image_id):
        info = self.image_info[image_id]
        return info['path']

    def load_image(self, image_id):
        info = self.image_info[image_id]
        fp = info['path']
        ds = pydicom.read_file(fp)
        image = ds.pixel_array
        # If grayscale. Convert to RGB for consistency.
        if len(image.shape) != 3 or image.shape[2] != 3:
            image = np.stack((image,) * 3, -1)
        return image

    def load_mask(self, image_id):
        info = self.image_info[image_id]
        annotations = info['annotations']
        count = len(annotations)
        if count == 0:
            mask = np.zeros((info['orig_height'], info['orig_width'], 1), dtype=np.uint8)
            class_ids = np.zeros((1,), dtype=np.int32)
        else:
            mask = np.zeros((info['orig_height'], info['orig_width'], count), dtype=np.uint8)
            class_ids = np.zeros((count,), dtype=np.int32)
            for i, a in enumerate(annotations):
                if a['Target'] == 1:
                    x = int(a['x'])
                    y = int(a['y'])
                    w = int(a['width'])
                    h = int(a['height'])
                    mask_instance = mask[:, :, i].copy()
                    cv2.rectangle(mask_instance, (x, y), (x+w, y+h), 255, -1)
                    mask[:, :, i] = mask_instance
                    class_ids[i] = 1
        return mask.astype(np.bool), class_ids.astype(np.int32)

# %%
# training dataset
anns = pd.read_csv(os.path.join(ROOT_DIR, 'stage_2_train_labels.csv'))
anns.head(6)

image_fps, image_annotations = parse_dataset(train_dicom_dir, anns=anns)

ds = pydicom.read_file(image_fps[0]) # read dicom image from filepath 
image = ds.pixel_array # get image array

ds
# Out:
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0016) SOP Class UID                       UI: Secondary Capture Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.276.0.7230010.3.1.4.8323329.7035.1517874329.236319
# (0008, 0020) Study Date                          DA: '19010101'
# (0008, 0030) Study Time                          TM: '000000.00'
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'CR'
# (0008, 0064) Conversion Type                     CS: 'WSD'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 103e) Series Description                  LO: 'view: AP'
# (0010, 0010) Patient's Name                      PN: '4039a6ff-ff73-42e2-a21d-359ba7177f7d'
# (0010, 0020) Patient ID                          LO: '4039a6ff-ff73-42e2-a21d-359ba7177f7d'
# (0010, 0030) Patient's Birth Date                DA: ''
# (0010, 0040) Patient's Sex                       CS: 'M'
# (0010, 1010) Patient's Age                       AS: '50'
# (0018, 0015) Body Part Examined                  CS: 'CHEST'
# (0018, 5101) View Position                       CS: 'AP'
# (0020, 000d) Study Instance UID                  UI: 1.2.276.0.7230010.3.1.2.8323329.7035.1517874329.236318
# (0020, 000e) Series Instance UID                 UI: 1.2.276.0.7230010.3.1.3.8323329.7035.1517874329.236317
# (0020, 0010) Study ID                            SH: ''
# (0020, 0011) Series Number                       IS: "1"
# (0020, 0013) Instance Number                     IS: "1"
# (0020, 0020) Patient Orientation                 CS: ''
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 1024
# (0028, 0011) Columns                             US: 1024
# (0028, 0030) Pixel Spacing                       DS: ['0.139', '0.139']
# (0028, 0100) Bits Allocated                      US: 8
# (0028, 0101) Bits Stored                         US: 8
# (0028, 0102) High Bit                            US: 7
# (0028, 0103) Pixel Representation                US: 0
# (0028, 2110) Lossy Image Compression             CS: '01'
# (0028, 2114) Lossy Image Compression Method      CS: 'ISO_10918_1'
# (7fe0, 0010) Pixel Data                          OB: Array of 127646 bytes

# %%
# Original DICOM image size: 1024 x 1024
ORIG_SIZE = 1024

# %% [markdown]
# **Split data into training and validation datasets**

# %%
######################################################################
# Modify this line to use more or fewer images for training/validation. 
# To use all images, do: image_fps_list = list(image_fps)
image_fps_list = list(image_fps) 
#####################################################################

# split dataset into training vs. validation dataset 
# split ratio is set to 0.9 vs. 0.1 (train vs. validation, respectively)
sorted(image_fps_list)
random.seed(42)
random.shuffle(image_fps_list)

validation_split = 0.1
split_index = int((1 - validation_split) * len(image_fps_list))

image_fps_train = image_fps_list[:split_index]
image_fps_val = image_fps_list[split_index:]

print(len(image_fps_train), len(image_fps_val))
# Out:
# 24015 2669

# %%
# prepare the training dataset
dataset_train = DetectorDataset(image_fps_train, image_annotations, ORIG_SIZE, ORIG_SIZE)
dataset_train.prepare()

# %%
# Show annotation(s) for a DICOM image 
test_fp = random.choice(image_fps_train)
image_annotations[test_fp]
# Out:
# [patientId    bff56724-dd71-4717-9ce7-9749d44361eb
#  x                                             NaN
#  y                                             NaN
#  width                                         NaN
#  height                                        NaN
#  Target                                          0
#  Name: 30152, dtype: object]

# %%
# prepare the validation dataset
dataset_val = DetectorDataset(image_fps_val, image_annotations, ORIG_SIZE, ORIG_SIZE)
dataset_val.prepare()

# %%
# Load and display random samples and their bounding boxes
# Suggestion: Run this a few times to see different examples. 

image_id = random.choice(dataset_train.image_ids)
image_fp = dataset_train.image_reference(image_id)
image = dataset_train.load_image(image_id)
mask, class_ids = dataset_train.load_mask(image_id)

print(image.shape)

plt.figure(figsize=(10, 10))
plt.subplot(1, 2, 1)
plt.imshow(image[:, :, 0], cmap='gray')
plt.axis('off')

plt.subplot(1, 2, 2)
masked = np.zeros(image.shape[:2])
for i in range(mask.shape[2]):
    masked += image[:, :, 0] * mask[:, :, i]
plt.imshow(masked, cmap='gray')
plt.axis('off')

print(image_fp)
print(class_ids)
# Out:
# (1024, 1024, 3)
# /Pneumonia_Detection/stage_2_train_images/43db9133-c2d9-42a9-bf91-2ea2bc256fbb.dcm
# [0]

# %% [markdown]
# **Image Augmentation**

# %%
# Image augmentation 
augmentation = iaa.SomeOf((0, 1), [
    iaa.Fliplr(0.5),
    iaa.Affine(
        scale={"x": (0.8, 1.2), "y": (0.8, 1.2)},
        translate_percent={"x": (-0.2, 0.2), "y": (-0.2, 0.2)},
        rotate=(-25, 25),
        shear=(-8, 8)
    ),
    iaa.Multiply((0.9, 1.1))
])

# %%
model = modellib.MaskRCNN(mode='training', config=config, model_dir=MODEL_DIR)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
# %%time

# Train Mask-RCNN Model 
import warnings 
warnings.filterwarnings("ignore")
model.train(dataset_train, dataset_val, 
            learning_rate=config.LEARNING_RATE, 
            epochs=10,
            layers='all',
            augmentation=None)

history = model.keras_model.history.history
# Out:
# Starting at epoch 0. LR=0.001
#
# Checkpoint Path: /Pneumonia_Detection/working/pneumonia20190504T2159/mask_rcnn_pneumonia_{epoch:04d}.h5
# Selecting layers to train
# conv1                  (Conv2D)
# bn_conv1               (BatchNorm)
# res2a_branch2a         (Conv2D)
# bn2a_branch2a          (BatchNorm)
# res2a_branch2b         (Conv2D)
# bn2a_branch2b          (BatchNorm)
# res2a_branch2c         (Conv2D)
# res2a_branch1          (Conv2D)
# bn2a_branch2c          (BatchNorm)
# bn2a_branch1           (BatchNorm)
# res2b_branch2a         (Conv2D)
# bn2b_branch2a          (BatchNorm)
# res2b_branch2b         (Conv2D)
# bn2b_branch2b          (BatchNorm)
# res2b_branch2c         (Conv2D)
# bn2b_branch2c          (BatchNorm)
# res2c_branch2a         (Conv2D)
# bn2c_branch2a          (BatchNorm)
# res2c_branch2b         (Conv2D)
# bn2c_branch2b          (BatchNorm)
# res2c_branch2c         (Conv2D)
# bn2c_branch2c          (BatchNorm)
# res3a_branch2a         (Conv2D)
# bn3a_branch2a          (BatchNorm)
# res3a_branch2b         (Conv2D)
# bn3a_branch2b          (BatchNorm)
# res3a_branch2c         (Conv2D)
# res3a_branch1          (Conv2D)
# bn3a_branch2c          (BatchNorm)
# bn3a_branch1           (BatchNorm)
# res3b_branch2a         (Conv2D)
# bn3b_branch2a          (BatchNorm)
# res3b_branch2b         (Conv2D)
# bn3b_branch2b          (BatchNorm)
# res3b_branch2c         (Conv2D)
# bn3b_branch2c          (BatchNorm)
# res3c_branch2a         (Conv2D)
# bn3c_branch2a          (BatchNorm)
# res3c_branch2b         (Conv2D)
# bn3c_branch2b          (BatchNorm)
# res3c_branch2c         (Conv2D)
# bn3c_branch2c          (BatchNorm)
# res3d_branch2a         (Conv2D)
# bn3d_branch2a          (BatchNorm)
# res3d_branch2b         (Conv2D)
# bn3d_branch2b          (BatchNorm)
# res3d_branch2c         (Conv2D)
# bn3d_branch2c          (BatchNorm)
# res4a_branch2a         (Conv2D)
# bn4a_branch2a          (BatchNorm)
# res4a_branch2b         (Conv2D)
# bn4a_branch2b          (BatchNorm)
# res4a_branch2c         (Conv2D)
# res4a_branch1          (Conv2D)
# bn4a_branch2c          (BatchNorm)
# bn4a_branch1           (BatchNorm)
# res4b_branch2a         (Conv2D)
# bn4b_branch2a          (BatchNorm)
# res4b_branch2b         (Conv2D)
# bn4b_branch2b          (BatchNorm)
# res4b_branch2c         (Conv2D)
# bn4b_branch2c          (BatchNorm)
# res4c_branch2a         (Conv2D)
# bn4c_branch2a          (BatchNorm)
# res4c_branch2b         (Conv2D)
# bn4c_branch2b          (BatchNorm)
# res4c_branch2c         (Conv2D)
# bn4c_branch2c          (BatchNorm)
# res4d_branch2a         (Conv2D)
# bn4d_branch2a          (BatchNorm)
# res4d_branch2b         (Conv2D)
# bn4d_branch2b          (BatchNorm)
# res4d_branch2c         (Conv2D)
# bn4d_branch2c          (BatchNorm)
# res4e_branch2a         (Conv2D)
# bn4e_branch2a          (BatchNorm)
# res4e_branch2b         (Conv2D)
# bn4e_branch2b          (BatchNorm)
# res4e_branch2c         (Conv2D)
# bn4e_branch2c          (BatchNorm)
# res4f_branch2a         (Conv2D)
# bn4f_branch2a          (BatchNorm)
# res4f_branch2b         (Conv2D)
# bn4f_branch2b          (BatchNorm)
# res4f_branch2c         (Conv2D)
# bn4f_branch2c          (BatchNorm)
# res5a_branch2a         (Conv2D)
# bn5a_branch2a          (BatchNorm)
# res5a_branch2b         (Conv2D)
# bn5a_branch2b          (BatchNorm)
# res5a_branch2c         (Conv2D)
# res5a_branch1          (Conv2D)
# bn5a_branch2c          (BatchNorm)
# bn5a_branch1           (BatchNorm)
# res5b_branch2a         (Conv2D)
# bn5b_branch2a          (BatchNorm)
# res5b_branch2b         (Conv2D)
# bn5b_branch2b          (BatchNorm)
# res5b_branch2c         (Conv2D)
# bn5b_branch2c          (BatchNorm)
# res5c_branch2a         (Conv2D)
# bn5c_branch2a          (BatchNorm)
# res5c_branch2b         (Conv2D)
# bn5c_branch2b          (BatchNorm)
# res5c_branch2c         (Conv2D)
# bn5c_branch2c          (BatchNorm)
# fpn_c5p5               (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/10
# 150/150 [==============================] - 562s 4s/step - loss: 2.5765 - rpn_class_loss: 0.1647 - rpn_bbox_loss: 0.7875 - mrcnn_class_loss: 0.2803 - mrcnn_bbox_loss: 0.7747 - mrcnn_mask_loss: 0.5693 - val_loss: 2.1314 - val_rpn_class_loss: 0.0383 - val_rpn_bbox_loss: 0.5930 - val_mrcnn_class_loss: 0.2960 - val_mrcnn_bbox_loss: 0.6709 - val_mrcnn_mask_loss: 0.5332
# Epoch 2/10
# 150/150 [==============================] - 230s 2s/step - loss: 1.9908 - rpn_class_loss: 0.0379 - rpn_bbox_loss: 0.5374 - mrcnn_class_loss: 0.2883 - mrcnn_bbox_loss: 0.6148 - mrcnn_mask_loss: 0.5124 - val_loss: 2.0363 - val_rpn_class_loss: 0.0373 - val_rpn_bbox_loss: 0.5474 - val_mrcnn_class_loss: 0.2817 - val_mrcnn_bbox_loss: 0.6566 - val_mrcnn_mask_loss: 0.5134
# Epoch 3/10
# 150/150 [==============================] - 429s 3s/step - loss: 1.8890 - rpn_class_loss: 0.0332 - rpn_bbox_loss: 0.4963 - mrcnn_class_loss: 0.2885 - mrcnn_bbox_loss: 0.5794 - mrcnn_mask_loss: 0.4915 - val_loss: 1.9499 - val_rpn_class_loss: 0.0335 - val_rpn_bbox_loss: 0.5928 - val_mrcnn_class_loss: 0.2824 - val_mrcnn_bbox_loss: 0.5478 - val_mrcnn_mask_loss: 0.4934
# Epoch 4/10
# 150/150 [==============================] - 421s 3s/step - loss: 1.8277 - rpn_class_loss: 0.0298 - rpn_bbox_loss: 0.4841 - mrcnn_class_loss: 0.2741 - mrcnn_bbox_loss: 0.5624 - mrcnn_mask_loss: 0.4772 - val_loss: 1.9185 - val_rpn_class_loss: 0.0321 - val_rpn_bbox_loss: 0.5370 - val_mrcnn_class_loss: 0.2916 - val_mrcnn_bbox_loss: 0.5864 - val_mrcnn_mask_loss: 0.4714
# Epoch 5/10
# 150/150 [==============================] - 417s 3s/step - loss: 1.8359 - rpn_class_loss: 0.0309 - rpn_bbox_loss: 0.4954 - mrcnn_class_loss: 0.2754 - mrcnn_bbox_loss: 0.5671 - mrcnn_mask_loss: 0.4669 - val_loss: 1.8374 - val_rpn_class_loss: 0.0303 - val_rpn_bbox_loss: 0.5013 - val_mrcnn_class_loss: 0.2659 - val_mrcnn_bbox_loss: 0.5677 - val_mrcnn_mask_loss: 0.4723
# Epoch 6/10
# 150/150 [==============================] - 398s 3s/step - loss: 1.7598 - rpn_class_loss: 0.0271 - rpn_bbox_loss: 0.4594 - mrcnn_class_loss: 0.2678 - mrcnn_bbox_loss: 0.5447 - mrcnn_mask_loss: 0.4607 - val_loss: 1.7766 - val_rpn_class_loss: 0.0284 - val_rpn_bbox_loss: 0.4409 - val_mrcnn_class_loss: 0.3044 - val_mrcnn_bbox_loss: 0.5387 - val_mrcnn_mask_loss: 0.4642
# Epoch 7/10
# 150/150 [==============================] - 427s 3s/step - loss: 1.7411 - rpn_class_loss: 0.0263 - rpn_bbox_loss: 0.4479 - mrcnn_class_loss: 0.2679 - mrcnn_bbox_loss: 0.5506 - mrcnn_mask_loss: 0.4485 - val_loss: 1.7851 - val_rpn_class_loss: 0.0294 - val_rpn_bbox_loss: 0.4737 - val_mrcnn_class_loss: 0.2763 - val_mrcnn_bbox_loss: 0.5460 - val_mrcnn_mask_loss: 0.4597
# Epoch 8/10
# 150/150 [==============================] - 436s 3s/step - loss: 1.7346 - rpn_class_loss: 0.0256 - rpn_bbox_loss: 0.4609 - mrcnn_class_loss: 0.2542 - mrcnn_bbox_loss: 0.5406 - mrcnn_mask_loss: 0.4533 - val_loss: 1.6926 - val_rpn_class_loss: 0.0241 - val_rpn_bbox_loss: 0.4574 - val_mrcnn_class_loss: 0.2457 - val_mrcnn_bbox_loss: 0.5183 - val_mrcnn_mask_loss: 0.4472
# Epoch 9/10
# 150/150 [==============================] - 413s 3s/step - loss: 1.6758 - rpn_class_loss: 0.0254 - rpn_bbox_loss: 0.4528 - mrcnn_class_loss: 0.2426 - mrcnn_bbox_loss: 0.5167 - mrcnn_mask_loss: 0.4383 - val_loss: 1.7860 - val_rpn_class_loss: 0.0248 - val_rpn_bbox_loss: 0.5143 - val_mrcnn_class_loss: 0.2415 - val_mrcnn_bbox_loss: 0.5469 - val_mrcnn_mask_loss: 0.4585
# Epoch 10/10
# 150/150 [==============================] - 426s 3s/step - loss: 1.6333 - rpn_class_loss: 0.0231 - rpn_bbox_loss: 0.4125 - mrcnn_class_loss: 0.2529 - mrcnn_bbox_loss: 0.5107 - mrcnn_mask_loss: 0.4341 - val_loss: 1.6921 - val_rpn_class_loss: 0.0254 - val_rpn_bbox_loss: 0.4584 - val_mrcnn_class_loss: 0.2351 - val_mrcnn_bbox_loss: 0.5293 - val_mrcnn_mask_loss: 0.4440
# CPU times: user 21min 26s, sys: 58.2 s, total: 22min 24s
# Wall time: 1h 13min 22s

# %%
#Train with augmentation
# %%time
model.train(dataset_train, dataset_val,
            learning_rate=config.LEARNING_RATE,
            epochs=20,
            layers='all',
            augmentation=augmentation)

new_history = model.keras_model.history.history
for k in new_history: history[k] = history[k] + new_history[k]
# Out:
# Starting at epoch 10. LR=0.001
#
# Checkpoint Path: /Pneumonia_Detection/working/pneumonia20190504T2159/mask_rcnn_pneumonia_{epoch:04d}.h5
# Selecting layers to train
# conv1                  (Conv2D)
# bn_conv1               (BatchNorm)
# res2a_branch2a         (Conv2D)
# bn2a_branch2a          (BatchNorm)
# res2a_branch2b         (Conv2D)
# bn2a_branch2b          (BatchNorm)
# res2a_branch2c         (Conv2D)
# res2a_branch1          (Conv2D)
# bn2a_branch2c          (BatchNorm)
# bn2a_branch1           (BatchNorm)
# res2b_branch2a         (Conv2D)
# bn2b_branch2a          (BatchNorm)
# res2b_branch2b         (Conv2D)
# bn2b_branch2b          (BatchNorm)
# res2b_branch2c         (Conv2D)
# bn2b_branch2c          (BatchNorm)
# res2c_branch2a         (Conv2D)
# bn2c_branch2a          (BatchNorm)
# res2c_branch2b         (Conv2D)
# bn2c_branch2b          (BatchNorm)
# res2c_branch2c         (Conv2D)
# bn2c_branch2c          (BatchNorm)
# res3a_branch2a         (Conv2D)
# bn3a_branch2a          (BatchNorm)
# res3a_branch2b         (Conv2D)
# bn3a_branch2b          (BatchNorm)
# res3a_branch2c         (Conv2D)
# res3a_branch1          (Conv2D)
# bn3a_branch2c          (BatchNorm)
# bn3a_branch1           (BatchNorm)
# res3b_branch2a         (Conv2D)
# bn3b_branch2a          (BatchNorm)
# res3b_branch2b         (Conv2D)
# bn3b_branch2b          (BatchNorm)
# res3b_branch2c         (Conv2D)
# bn3b_branch2c          (BatchNorm)
# res3c_branch2a         (Conv2D)
# bn3c_branch2a          (BatchNorm)
# res3c_branch2b         (Conv2D)
# bn3c_branch2b          (BatchNorm)
# res3c_branch2c         (Conv2D)
# bn3c_branch2c          (BatchNorm)
# res3d_branch2a         (Conv2D)
# bn3d_branch2a          (BatchNorm)
# res3d_branch2b         (Conv2D)
# bn3d_branch2b          (BatchNorm)
# res3d_branch2c         (Conv2D)
# bn3d_branch2c          (BatchNorm)
# res4a_branch2a         (Conv2D)
# bn4a_branch2a          (BatchNorm)
# res4a_branch2b         (Conv2D)
# bn4a_branch2b          (BatchNorm)
# res4a_branch2c         (Conv2D)
# res4a_branch1          (Conv2D)
# bn4a_branch2c          (BatchNorm)
# bn4a_branch1           (BatchNorm)
# res4b_branch2a         (Conv2D)
# bn4b_branch2a          (BatchNorm)
# res4b_branch2b         (Conv2D)
# bn4b_branch2b          (BatchNorm)
# res4b_branch2c         (Conv2D)
# bn4b_branch2c          (BatchNorm)
# res4c_branch2a         (Conv2D)
# bn4c_branch2a          (BatchNorm)
# res4c_branch2b         (Conv2D)
# bn4c_branch2b          (BatchNorm)
# res4c_branch2c         (Conv2D)
# bn4c_branch2c          (BatchNorm)
# res4d_branch2a         (Conv2D)
# bn4d_branch2a          (BatchNorm)
# res4d_branch2b         (Conv2D)
# bn4d_branch2b          (BatchNorm)
# res4d_branch2c         (Conv2D)
# bn4d_branch2c          (BatchNorm)
# res4e_branch2a         (Conv2D)
# bn4e_branch2a          (BatchNorm)
# res4e_branch2b         (Conv2D)
# bn4e_branch2b          (BatchNorm)
# res4e_branch2c         (Conv2D)
# bn4e_branch2c          (BatchNorm)
# res4f_branch2a         (Conv2D)
# bn4f_branch2a          (BatchNorm)
# res4f_branch2b         (Conv2D)
# bn4f_branch2b          (BatchNorm)
# res4f_branch2c         (Conv2D)
# bn4f_branch2c          (BatchNorm)
# res5a_branch2a         (Conv2D)
# bn5a_branch2a          (BatchNorm)
# res5a_branch2b         (Conv2D)
# bn5a_branch2b          (BatchNorm)
# res5a_branch2c         (Conv2D)
# res5a_branch1          (Conv2D)
# bn5a_branch2c          (BatchNorm)
# bn5a_branch1           (BatchNorm)
# res5b_branch2a         (Conv2D)
# bn5b_branch2a          (BatchNorm)
# res5b_branch2b         (Conv2D)
# bn5b_branch2b          (BatchNorm)
# res5b_branch2c         (Conv2D)
# bn5b_branch2c          (BatchNorm)
# res5c_branch2a         (Conv2D)
# bn5c_branch2a          (BatchNorm)
# res5c_branch2b         (Conv2D)
# bn5c_branch2b          (BatchNorm)
# res5c_branch2c         (Conv2D)
# bn5c_branch2c          (BatchNorm)
# fpn_c5p5               (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# Epoch 11/20
# 150/150 [==============================] - 562s 4s/step - loss: 1.6851 - rpn_class_loss: 0.0223 - rpn_bbox_loss: 0.4183 - mrcnn_class_loss: 0.2716 - mrcnn_bbox_loss: 0.5216 - mrcnn_mask_loss: 0.4512 - val_loss: 1.7249 - val_rpn_class_loss: 0.0251 - val_rpn_bbox_loss: 0.4270 - val_mrcnn_class_loss: 0.2946 - val_mrcnn_bbox_loss: 0.5369 - val_mrcnn_mask_loss: 0.4412
# Epoch 12/20
# 150/150 [==============================] - 410s 3s/step - loss: 1.7331 - rpn_class_loss: 0.0234 - rpn_bbox_loss: 0.4605 - mrcnn_class_loss: 0.2680 - mrcnn_bbox_loss: 0.5307 - mrcnn_mask_loss: 0.4505 - val_loss: 1.7112 - val_rpn_class_loss: 0.0239 - val_rpn_bbox_loss: 0.4811 - val_mrcnn_class_loss: 0.2453 - val_mrcnn_bbox_loss: 0.5292 - val_mrcnn_mask_loss: 0.4316
# Epoch 13/20
# 150/150 [==============================] - 447s 3s/step - loss: 1.6872 - rpn_class_loss: 0.0209 - rpn_bbox_loss: 0.4231 - mrcnn_class_loss: 0.2690 - mrcnn_bbox_loss: 0.5230 - mrcnn_mask_loss: 0.4512 - val_loss: 1.7450 - val_rpn_class_loss: 0.0219 - val_rpn_bbox_loss: 0.5103 - val_mrcnn_class_loss: 0.2431 - val_mrcnn_bbox_loss: 0.5300 - val_mrcnn_mask_loss: 0.4398
# Epoch 14/20
# 150/150 [==============================] - 436s 3s/step - loss: 1.7131 - rpn_class_loss: 0.0208 - rpn_bbox_loss: 0.4732 - mrcnn_class_loss: 0.2605 - mrcnn_bbox_loss: 0.5084 - mrcnn_mask_loss: 0.4501 - val_loss: 1.7024 - val_rpn_class_loss: 0.0222 - val_rpn_bbox_loss: 0.4515 - val_mrcnn_class_loss: 0.2783 - val_mrcnn_bbox_loss: 0.5146 - val_mrcnn_mask_loss: 0.4357
# Epoch 15/20
# 150/150 [==============================] - 424s 3s/step - loss: 1.6986 - rpn_class_loss: 0.0206 - rpn_bbox_loss: 0.4735 - mrcnn_class_loss: 0.2551 - mrcnn_bbox_loss: 0.5029 - mrcnn_mask_loss: 0.4466 - val_loss: 1.7094 - val_rpn_class_loss: 0.0217 - val_rpn_bbox_loss: 0.5589 - val_mrcnn_class_loss: 0.2214 - val_mrcnn_bbox_loss: 0.4796 - val_mrcnn_mask_loss: 0.4279
# Epoch 16/20
# 150/150 [==============================] - 403s 3s/step - loss: 1.6581 - rpn_class_loss: 0.0189 - rpn_bbox_loss: 0.4439 - mrcnn_class_loss: 0.2586 - mrcnn_bbox_loss: 0.4929 - mrcnn_mask_loss: 0.4438 - val_loss: 1.6390 - val_rpn_class_loss: 0.0207 - val_rpn_bbox_loss: 0.4249 - val_mrcnn_class_loss: 0.2573 - val_mrcnn_bbox_loss: 0.5138 - val_mrcnn_mask_loss: 0.4222
# Epoch 17/20
# 150/150 [==============================] - 436s 3s/step - loss: 1.6433 - rpn_class_loss: 0.0190 - rpn_bbox_loss: 0.4328 - mrcnn_class_loss: 0.2569 - mrcnn_bbox_loss: 0.4964 - mrcnn_mask_loss: 0.4382 - val_loss: 1.6732 - val_rpn_class_loss: 0.0223 - val_rpn_bbox_loss: 0.5022 - val_mrcnn_class_loss: 0.2346 - val_mrcnn_bbox_loss: 0.4846 - val_mrcnn_mask_loss: 0.4295
# Epoch 18/20
# 150/150 [==============================] - 438s 3s/step - loss: 1.6380 - rpn_class_loss: 0.0188 - rpn_bbox_loss: 0.4316 - mrcnn_class_loss: 0.2454 - mrcnn_bbox_loss: 0.4969 - mrcnn_mask_loss: 0.4452 - val_loss: 1.6146 - val_rpn_class_loss: 0.0167 - val_rpn_bbox_loss: 0.4523 - val_mrcnn_class_loss: 0.2443 - val_mrcnn_bbox_loss: 0.4882 - val_mrcnn_mask_loss: 0.4131
# Epoch 19/20
# 150/150 [==============================] - 424s 3s/step - loss: 1.6516 - rpn_class_loss: 0.0199 - rpn_bbox_loss: 0.4641 - mrcnn_class_loss: 0.2431 - mrcnn_bbox_loss: 0.4816 - mrcnn_mask_loss: 0.4428 - val_loss: 1.6605 - val_rpn_class_loss: 0.0195 - val_rpn_bbox_loss: 0.4731 - val_mrcnn_class_loss: 0.2377 - val_mrcnn_bbox_loss: 0.4941 - val_mrcnn_mask_loss: 0.4361
# Epoch 20/20
# 150/150 [==============================] - 444s 3s/step - loss: 1.6390 - rpn_class_loss: 0.0183 - rpn_bbox_loss: 0.4516 - mrcnn_class_loss: 0.2421 - mrcnn_bbox_loss: 0.4848 - mrcnn_mask_loss: 0.4422 - val_loss: 1.6587 - val_rpn_class_loss: 0.0191 - val_rpn_bbox_loss: 0.5046 - val_mrcnn_class_loss: 0.2351 - val_mrcnn_bbox_loss: 0.4852 - val_mrcnn_mask_loss: 0.4147
# CPU times: user 22min 53s, sys: 53.4 s, total: 23min 46s
# Wall time: 1h 14min 33s

# %%
#Train with a lower learning rate
# %%time
model.train(dataset_train, dataset_val,
            learning_rate=config.LEARNING_RATE/5,
            epochs=30,
            layers='all',
            augmentation=augmentation)

new_history = model.keras_model.history.history
for k in new_history: history[k] = history[k] + new_history[k]
# Out:
# Starting at epoch 20. LR=0.0002
#
# Checkpoint Path: /Pneumonia_Detection/working/pneumonia20190504T2159/mask_rcnn_pneumonia_{epoch:04d}.h5
# Selecting layers to train
# conv1                  (Conv2D)
# bn_conv1               (BatchNorm)
# res2a_branch2a         (Conv2D)
# bn2a_branch2a          (BatchNorm)
# res2a_branch2b         (Conv2D)
# bn2a_branch2b          (BatchNorm)
# res2a_branch2c         (Conv2D)
# res2a_branch1          (Conv2D)
# bn2a_branch2c          (BatchNorm)
# bn2a_branch1           (BatchNorm)
# res2b_branch2a         (Conv2D)
# bn2b_branch2a          (BatchNorm)
# res2b_branch2b         (Conv2D)
# bn2b_branch2b          (BatchNorm)
# res2b_branch2c         (Conv2D)
# bn2b_branch2c          (BatchNorm)
# res2c_branch2a         (Conv2D)
# bn2c_branch2a          (BatchNorm)
# res2c_branch2b         (Conv2D)
# bn2c_branch2b          (BatchNorm)
# res2c_branch2c         (Conv2D)
# bn2c_branch2c          (BatchNorm)
# res3a_branch2a         (Conv2D)
# bn3a_branch2a          (BatchNorm)
# res3a_branch2b         (Conv2D)
# bn3a_branch2b          (BatchNorm)
# res3a_branch2c         (Conv2D)
# res3a_branch1          (Conv2D)
# bn3a_branch2c          (BatchNorm)
# bn3a_branch1           (BatchNorm)
# res3b_branch2a         (Conv2D)
# bn3b_branch2a          (BatchNorm)
# res3b_branch2b         (Conv2D)
# bn3b_branch2b          (BatchNorm)
# res3b_branch2c         (Conv2D)
# bn3b_branch2c          (BatchNorm)
# res3c_branch2a         (Conv2D)
# bn3c_branch2a          (BatchNorm)
# res3c_branch2b         (Conv2D)
# bn3c_branch2b          (BatchNorm)
# res3c_branch2c         (Conv2D)
# bn3c_branch2c          (BatchNorm)
# res3d_branch2a         (Conv2D)
# bn3d_branch2a          (BatchNorm)
# res3d_branch2b         (Conv2D)
# bn3d_branch2b          (BatchNorm)
# res3d_branch2c         (Conv2D)
# bn3d_branch2c          (BatchNorm)
# res4a_branch2a         (Conv2D)
# bn4a_branch2a          (BatchNorm)
# res4a_branch2b         (Conv2D)
# bn4a_branch2b          (BatchNorm)
# res4a_branch2c         (Conv2D)
# res4a_branch1          (Conv2D)
# bn4a_branch2c          (BatchNorm)
# bn4a_branch1           (BatchNorm)
# res4b_branch2a         (Conv2D)
# bn4b_branch2a          (BatchNorm)
# res4b_branch2b         (Conv2D)
# bn4b_branch2b          (BatchNorm)
# res4b_branch2c         (Conv2D)
# bn4b_branch2c          (BatchNorm)
# res4c_branch2a         (Conv2D)
# bn4c_branch2a          (BatchNorm)
# res4c_branch2b         (Conv2D)
# bn4c_branch2b          (BatchNorm)
# res4c_branch2c         (Conv2D)
# bn4c_branch2c          (BatchNorm)
# res4d_branch2a         (Conv2D)
# bn4d_branch2a          (BatchNorm)
# res4d_branch2b         (Conv2D)
# bn4d_branch2b          (BatchNorm)
# res4d_branch2c         (Conv2D)
# bn4d_branch2c          (BatchNorm)
# res4e_branch2a         (Conv2D)
# bn4e_branch2a          (BatchNorm)
# res4e_branch2b         (Conv2D)
# bn4e_branch2b          (BatchNorm)
# res4e_branch2c         (Conv2D)
# bn4e_branch2c          (BatchNorm)
# res4f_branch2a         (Conv2D)
# bn4f_branch2a          (BatchNorm)
# res4f_branch2b         (Conv2D)
# bn4f_branch2b          (BatchNorm)
# res4f_branch2c         (Conv2D)
# bn4f_branch2c          (BatchNorm)
# res5a_branch2a         (Conv2D)
# bn5a_branch2a          (BatchNorm)
# res5a_branch2b         (Conv2D)
# bn5a_branch2b          (BatchNorm)
# res5a_branch2c         (Conv2D)
# res5a_branch1          (Conv2D)
# bn5a_branch2c          (BatchNorm)
# bn5a_branch1           (BatchNorm)
# res5b_branch2a         (Conv2D)
# bn5b_branch2a          (BatchNorm)
# res5b_branch2b         (Conv2D)
# bn5b_branch2b          (BatchNorm)
# res5b_branch2c         (Conv2D)
# bn5b_branch2c          (BatchNorm)
# res5c_branch2a         (Conv2D)
# bn5c_branch2a          (BatchNorm)
# res5c_branch2b         (Conv2D)
# bn5c_branch2b          (BatchNorm)
# res5c_branch2c         (Conv2D)
# bn5c_branch2c          (BatchNorm)
# fpn_c5p5               (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# Epoch 21/30
# 150/150 [==============================] - 576s 4s/step - loss: 1.5622 - rpn_class_loss: 0.0173 - rpn_bbox_loss: 0.4095 - mrcnn_class_loss: 0.2423 - mrcnn_bbox_loss: 0.4637 - mrcnn_mask_loss: 0.4293 - val_loss: 1.5303 - val_rpn_class_loss: 0.0171 - val_rpn_bbox_loss: 0.4205 - val_mrcnn_class_loss: 0.2286 - val_mrcnn_bbox_loss: 0.4537 - val_mrcnn_mask_loss: 0.4104
# Epoch 22/30
# 150/150 [==============================] - 420s 3s/step - loss: 1.5828 - rpn_class_loss: 0.0183 - rpn_bbox_loss: 0.4490 - mrcnn_class_loss: 0.2305 - mrcnn_bbox_loss: 0.4615 - mrcnn_mask_loss: 0.4235 - val_loss: 1.5968 - val_rpn_class_loss: 0.0209 - val_rpn_bbox_loss: 0.4543 - val_mrcnn_class_loss: 0.2419 - val_mrcnn_bbox_loss: 0.4660 - val_mrcnn_mask_loss: 0.4137
# Epoch 23/30
# 150/150 [==============================] - 425s 3s/step - loss: 1.5333 - rpn_class_loss: 0.0172 - rpn_bbox_loss: 0.3908 - mrcnn_class_loss: 0.2430 - mrcnn_bbox_loss: 0.4556 - mrcnn_mask_loss: 0.4267 - val_loss: 1.5799 - val_rpn_class_loss: 0.0174 - val_rpn_bbox_loss: 0.4610 - val_mrcnn_class_loss: 0.2368 - val_mrcnn_bbox_loss: 0.4551 - val_mrcnn_mask_loss: 0.4094
# Epoch 24/30
# 150/150 [==============================] - 425s 3s/step - loss: 1.5300 - rpn_class_loss: 0.0169 - rpn_bbox_loss: 0.4135 - mrcnn_class_loss: 0.2313 - mrcnn_bbox_loss: 0.4492 - mrcnn_mask_loss: 0.4191 - val_loss: 1.5550 - val_rpn_class_loss: 0.0184 - val_rpn_bbox_loss: 0.4423 - val_mrcnn_class_loss: 0.2299 - val_mrcnn_bbox_loss: 0.4583 - val_mrcnn_mask_loss: 0.4062
# Epoch 25/30
# 150/150 [==============================] - 430s 3s/step - loss: 1.5404 - rpn_class_loss: 0.0170 - rpn_bbox_loss: 0.4133 - mrcnn_class_loss: 0.2393 - mrcnn_bbox_loss: 0.4495 - mrcnn_mask_loss: 0.4213 - val_loss: 1.5734 - val_rpn_class_loss: 0.0183 - val_rpn_bbox_loss: 0.5003 - val_mrcnn_class_loss: 0.2004 - val_mrcnn_bbox_loss: 0.4420 - val_mrcnn_mask_loss: 0.4124
# Epoch 26/30
# 150/150 [==============================] - 406s 3s/step - loss: 1.5165 - rpn_class_loss: 0.0158 - rpn_bbox_loss: 0.3942 - mrcnn_class_loss: 0.2364 - mrcnn_bbox_loss: 0.4479 - mrcnn_mask_loss: 0.4222 - val_loss: 1.5074 - val_rpn_class_loss: 0.0167 - val_rpn_bbox_loss: 0.3947 - val_mrcnn_class_loss: 0.2429 - val_mrcnn_bbox_loss: 0.4397 - val_mrcnn_mask_loss: 0.4133
# Epoch 27/30
# 150/150 [==============================] - 428s 3s/step - loss: 1.4938 - rpn_class_loss: 0.0163 - rpn_bbox_loss: 0.3720 - mrcnn_class_loss: 0.2401 - mrcnn_bbox_loss: 0.4452 - mrcnn_mask_loss: 0.4202 - val_loss: 1.5839 - val_rpn_class_loss: 0.0196 - val_rpn_bbox_loss: 0.4859 - val_mrcnn_class_loss: 0.2206 - val_mrcnn_bbox_loss: 0.4416 - val_mrcnn_mask_loss: 0.4161
# Epoch 28/30
# 150/150 [==============================] - 438s 3s/step - loss: 1.4851 - rpn_class_loss: 0.0160 - rpn_bbox_loss: 0.3796 - mrcnn_class_loss: 0.2207 - mrcnn_bbox_loss: 0.4471 - mrcnn_mask_loss: 0.4216 - val_loss: 1.4847 - val_rpn_class_loss: 0.0154 - val_rpn_bbox_loss: 0.3973 - val_mrcnn_class_loss: 0.2251 - val_mrcnn_bbox_loss: 0.4419 - val_mrcnn_mask_loss: 0.4050
# Epoch 29/30
# 150/150 [==============================] - 428s 3s/step - loss: 1.4753 - rpn_class_loss: 0.0166 - rpn_bbox_loss: 0.3849 - mrcnn_class_loss: 0.2205 - mrcnn_bbox_loss: 0.4320 - mrcnn_mask_loss: 0.4213 - val_loss: 1.5001 - val_rpn_class_loss: 0.0166 - val_rpn_bbox_loss: 0.4244 - val_mrcnn_class_loss: 0.2125 - val_mrcnn_bbox_loss: 0.4399 - val_mrcnn_mask_loss: 0.4065
# Epoch 30/30
# 150/150 [==============================] - 427s 3s/step - loss: 1.4537 - rpn_class_loss: 0.0158 - rpn_bbox_loss: 0.3689 - mrcnn_class_loss: 0.2227 - mrcnn_bbox_loss: 0.4285 - mrcnn_mask_loss: 0.4178 - val_loss: 1.5599 - val_rpn_class_loss: 0.0176 - val_rpn_bbox_loss: 0.4758 - val_mrcnn_class_loss: 0.2037 - val_mrcnn_bbox_loss: 0.4497 - val_mrcnn_mask_loss: 0.4132
# CPU times: user 22min 39s, sys: 54.2 s, total: 23min 33s
# Wall time: 1h 14min 15s

# %%
#Train with augmentation
# %%time
model.train(dataset_train, dataset_val,
            learning_rate=config.LEARNING_RATE,
            epochs=40,
            layers='all',
            augmentation=augmentation)

new_history = model.keras_model.history.history
for k in new_history: history[k] = history[k] + new_history[k]
# Out:
# Starting at epoch 30. LR=0.001
#
# Checkpoint Path: /Pneumonia_Detection/working/pneumonia20190504T2159/mask_rcnn_pneumonia_{epoch:04d}.h5
# Selecting layers to train
# conv1                  (Conv2D)
# bn_conv1               (BatchNorm)
# res2a_branch2a         (Conv2D)
# bn2a_branch2a          (BatchNorm)
# res2a_branch2b         (Conv2D)
# bn2a_branch2b          (BatchNorm)
# res2a_branch2c         (Conv2D)
# res2a_branch1          (Conv2D)
# bn2a_branch2c          (BatchNorm)
# bn2a_branch1           (BatchNorm)
# res2b_branch2a         (Conv2D)
# bn2b_branch2a          (BatchNorm)
# res2b_branch2b         (Conv2D)
# bn2b_branch2b          (BatchNorm)
# res2b_branch2c         (Conv2D)
# bn2b_branch2c          (BatchNorm)
# res2c_branch2a         (Conv2D)
# bn2c_branch2a          (BatchNorm)
# res2c_branch2b         (Conv2D)
# bn2c_branch2b          (BatchNorm)
# res2c_branch2c         (Conv2D)
# bn2c_branch2c          (BatchNorm)
# res3a_branch2a         (Conv2D)
# bn3a_branch2a          (BatchNorm)
# res3a_branch2b         (Conv2D)
# bn3a_branch2b          (BatchNorm)
# res3a_branch2c         (Conv2D)
# res3a_branch1          (Conv2D)
# bn3a_branch2c          (BatchNorm)
# bn3a_branch1           (BatchNorm)
# res3b_branch2a         (Conv2D)
# bn3b_branch2a          (BatchNorm)
# res3b_branch2b         (Conv2D)
# bn3b_branch2b          (BatchNorm)
# res3b_branch2c         (Conv2D)
# bn3b_branch2c          (BatchNorm)
# res3c_branch2a         (Conv2D)
# bn3c_branch2a          (BatchNorm)
# res3c_branch2b         (Conv2D)
# bn3c_branch2b          (BatchNorm)
# res3c_branch2c         (Conv2D)
# bn3c_branch2c          (BatchNorm)
# res3d_branch2a         (Conv2D)
# bn3d_branch2a          (BatchNorm)
# res3d_branch2b         (Conv2D)
# bn3d_branch2b          (BatchNorm)
# res3d_branch2c         (Conv2D)
# bn3d_branch2c          (BatchNorm)
# res4a_branch2a         (Conv2D)
# bn4a_branch2a          (BatchNorm)
# res4a_branch2b         (Conv2D)
# bn4a_branch2b          (BatchNorm)
# res4a_branch2c         (Conv2D)
# res4a_branch1          (Conv2D)
# bn4a_branch2c          (BatchNorm)
# bn4a_branch1           (BatchNorm)
# res4b_branch2a         (Conv2D)
# bn4b_branch2a          (BatchNorm)
# res4b_branch2b         (Conv2D)
# bn4b_branch2b          (BatchNorm)
# res4b_branch2c         (Conv2D)
# bn4b_branch2c          (BatchNorm)
# res4c_branch2a         (Conv2D)
# bn4c_branch2a          (BatchNorm)
# res4c_branch2b         (Conv2D)
# bn4c_branch2b          (BatchNorm)
# res4c_branch2c         (Conv2D)
# bn4c_branch2c          (BatchNorm)
# res4d_branch2a         (Conv2D)
# bn4d_branch2a          (BatchNorm)
# res4d_branch2b         (Conv2D)
# bn4d_branch2b          (BatchNorm)
# res4d_branch2c         (Conv2D)
# bn4d_branch2c          (BatchNorm)
# res4e_branch2a         (Conv2D)
# bn4e_branch2a          (BatchNorm)
# res4e_branch2b         (Conv2D)
# bn4e_branch2b          (BatchNorm)
# res4e_branch2c         (Conv2D)
# bn4e_branch2c          (BatchNorm)
# res4f_branch2a         (Conv2D)
# bn4f_branch2a          (BatchNorm)
# res4f_branch2b         (Conv2D)
# bn4f_branch2b          (BatchNorm)
# res4f_branch2c         (Conv2D)
# bn4f_branch2c          (BatchNorm)
# res5a_branch2a         (Conv2D)
# bn5a_branch2a          (BatchNorm)
# res5a_branch2b         (Conv2D)
# bn5a_branch2b          (BatchNorm)
# res5a_branch2c         (Conv2D)
# res5a_branch1          (Conv2D)
# bn5a_branch2c          (BatchNorm)
# bn5a_branch1           (BatchNorm)
# res5b_branch2a         (Conv2D)
# bn5b_branch2a          (BatchNorm)
# res5b_branch2b         (Conv2D)
# bn5b_branch2b          (BatchNorm)
# res5b_branch2c         (Conv2D)
# bn5b_branch2c          (BatchNorm)
# res5c_branch2a         (Conv2D)
# bn5c_branch2a          (BatchNorm)
# res5c_branch2b         (Conv2D)
# bn5c_branch2b          (BatchNorm)
# res5c_branch2c         (Conv2D)
# bn5c_branch2c          (BatchNorm)
# fpn_c5p5               (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# Epoch 31/40
# 150/150 [==============================] - 575s 4s/step - loss: 1.5478 - rpn_class_loss: 0.0171 - rpn_bbox_loss: 0.3986 - mrcnn_class_loss: 0.2405 - mrcnn_bbox_loss: 0.4602 - mrcnn_mask_loss: 0.4314 - val_loss: 1.5835 - val_rpn_class_loss: 0.0175 - val_rpn_bbox_loss: 0.4505 - val_mrcnn_class_loss: 0.2340 - val_mrcnn_bbox_loss: 0.4665 - val_mrcnn_mask_loss: 0.4149
# Epoch 32/40
# 150/150 [==============================] - 413s 3s/step - loss: 1.6114 - rpn_class_loss: 0.0180 - rpn_bbox_loss: 0.4500 - mrcnn_class_loss: 0.2415 - mrcnn_bbox_loss: 0.4744 - mrcnn_mask_loss: 0.4275 - val_loss: 1.7103 - val_rpn_class_loss: 0.0194 - val_rpn_bbox_loss: 0.5238 - val_mrcnn_class_loss: 0.2491 - val_mrcnn_bbox_loss: 0.4986 - val_mrcnn_mask_loss: 0.4196
# Epoch 33/40
# 150/150 [==============================] - 424s 3s/step - loss: 1.5881 - rpn_class_loss: 0.0170 - rpn_bbox_loss: 0.4096 - mrcnn_class_loss: 0.2596 - mrcnn_bbox_loss: 0.4709 - mrcnn_mask_loss: 0.4310 - val_loss: 1.6635 - val_rpn_class_loss: 0.0174 - val_rpn_bbox_loss: 0.5013 - val_mrcnn_class_loss: 0.2546 - val_mrcnn_bbox_loss: 0.4791 - val_mrcnn_mask_loss: 0.4111
# Epoch 34/40
# 150/150 [==============================] - 426s 3s/step - loss: 1.5945 - rpn_class_loss: 0.0167 - rpn_bbox_loss: 0.4338 - mrcnn_class_loss: 0.2514 - mrcnn_bbox_loss: 0.4686 - mrcnn_mask_loss: 0.4240 - val_loss: 1.5953 - val_rpn_class_loss: 0.0189 - val_rpn_bbox_loss: 0.4291 - val_mrcnn_class_loss: 0.2586 - val_mrcnn_bbox_loss: 0.4655 - val_mrcnn_mask_loss: 0.4232
# Epoch 35/40
# 150/150 [==============================] - 428s 3s/step - loss: 1.5844 - rpn_class_loss: 0.0171 - rpn_bbox_loss: 0.4366 - mrcnn_class_loss: 0.2500 - mrcnn_bbox_loss: 0.4551 - mrcnn_mask_loss: 0.4256 - val_loss: 1.6687 - val_rpn_class_loss: 0.0177 - val_rpn_bbox_loss: 0.5396 - val_mrcnn_class_loss: 0.2220 - val_mrcnn_bbox_loss: 0.4648 - val_mrcnn_mask_loss: 0.4246
# Epoch 36/40
# 150/150 [==============================] - 404s 3s/step - loss: 1.5826 - rpn_class_loss: 0.0161 - rpn_bbox_loss: 0.4094 - mrcnn_class_loss: 0.2553 - mrcnn_bbox_loss: 0.4722 - mrcnn_mask_loss: 0.4296 - val_loss: 1.5353 - val_rpn_class_loss: 0.0163 - val_rpn_bbox_loss: 0.3972 - val_mrcnn_class_loss: 0.2421 - val_mrcnn_bbox_loss: 0.4689 - val_mrcnn_mask_loss: 0.4107
# Epoch 37/40
# 150/150 [==============================] - 429s 3s/step - loss: 1.5203 - rpn_class_loss: 0.0160 - rpn_bbox_loss: 0.3854 - mrcnn_class_loss: 0.2433 - mrcnn_bbox_loss: 0.4532 - mrcnn_mask_loss: 0.4223 - val_loss: 1.6092 - val_rpn_class_loss: 0.0186 - val_rpn_bbox_loss: 0.4937 - val_mrcnn_class_loss: 0.2299 - val_mrcnn_bbox_loss: 0.4535 - val_mrcnn_mask_loss: 0.4135
# Epoch 38/40
# 150/150 [==============================] - 442s 3s/step - loss: 1.4809 - rpn_class_loss: 0.0154 - rpn_bbox_loss: 0.3800 - mrcnn_class_loss: 0.2178 - mrcnn_bbox_loss: 0.4472 - mrcnn_mask_loss: 0.4204 - val_loss: 1.5295 - val_rpn_class_loss: 0.0149 - val_rpn_bbox_loss: 0.4357 - val_mrcnn_class_loss: 0.2197 - val_mrcnn_bbox_loss: 0.4555 - val_mrcnn_mask_loss: 0.4036
# Epoch 39/40
# 150/150 [==============================] - 424s 3s/step - loss: 1.4724 - rpn_class_loss: 0.0160 - rpn_bbox_loss: 0.3983 - mrcnn_class_loss: 0.2156 - mrcnn_bbox_loss: 0.4278 - mrcnn_mask_loss: 0.4147 - val_loss: 1.5501 - val_rpn_class_loss: 0.0167 - val_rpn_bbox_loss: 0.4546 - val_mrcnn_class_loss: 0.2144 - val_mrcnn_bbox_loss: 0.4456 - val_mrcnn_mask_loss: 0.4188
# Epoch 40/40
# 150/150 [==============================] - 431s 3s/step - loss: 1.4478 - rpn_class_loss: 0.0146 - rpn_bbox_loss: 0.3651 - mrcnn_class_loss: 0.2196 - mrcnn_bbox_loss: 0.4280 - mrcnn_mask_loss: 0.4205 - val_loss: 1.5643 - val_rpn_class_loss: 0.0162 - val_rpn_bbox_loss: 0.4893 - val_mrcnn_class_loss: 0.2134 - val_mrcnn_bbox_loss: 0.4458 - val_mrcnn_mask_loss: 0.3996
# CPU times: user 22min 12s, sys: 54.4 s, total: 23min 6s
# Wall time: 1h 14min 14s

# %%
epochs = range(1,len(next(iter(history.values())))+1)
log2 = pd.DataFrame(history, index=epochs)

# %%
#Save the loss data in a file
from google.colab import files

log2.to_csv('log2.csv', index=False)
files.download('log2.csv')

# %%
files.download('log2.csv')

# %%
plt.figure(figsize=(17,5))

plt.subplot(131)
plt.plot(epochs, history["loss"], label="Train loss")
plt.plot(epochs, history["val_loss"], label="Valid loss")
plt.legend()
plt.subplot(132)
plt.plot(epochs, history["mrcnn_class_loss"], label="Train class ce")
plt.plot(epochs, history["val_mrcnn_class_loss"], label="Valid class ce")
plt.legend()
plt.subplot(133)
plt.plot(epochs, history["mrcnn_bbox_loss"], label="Train box loss")
plt.plot(epochs, history["val_mrcnn_bbox_loss"], label="Valid box loss")
plt.legend()

plt.show()

# %%
#Find the best epoch
best_epoch = np.argmin(history["val_loss"])
print("Best Epoch:", best_epoch + 1, history["val_loss"][best_epoch])
# Out:
# Best Epoch: 28 1.4846885013580322

# %%
# select trained model 
dir_names = next(os.walk(model.model_dir))[1]
key = config.NAME.lower()
dir_names = filter(lambda f: f.startswith(key), dir_names)
dir_names = sorted(dir_names)

if not dir_names:
    import errno
    raise FileNotFoundError(
        errno.ENOENT,
        "Could not find model directory under {}".format(self.model_dir))
    
fps = []
# Pick last directory
for d in dir_names: 
    dir_name = os.path.join(model.model_dir, d)
    # Find the last checkpoint
    checkpoints = next(os.walk(dir_name))[2]
    checkpoints = filter(lambda f: f.startswith("mask_rcnn"), checkpoints)
    checkpoints = sorted(checkpoints)
    if not checkpoints:
        print('No weight files in {}'.format(dir_name))
    else:
        checkpoint = os.path.join(dir_name, checkpoints[best_epoch])
        fps.append(checkpoint)

model_path = sorted(fps)[-1]
print('Found model {}'.format(model_path))
# Out:
# Found model /Pneumonia_Detection/working/pneumonia20190504T2159/mask_rcnn_pneumonia_0028.h5

# %%
class InferenceConfig(DetectorConfig):
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1

inference_config = InferenceConfig()

# Recreate the model in inference mode
model = modellib.MaskRCNN(mode='inference', 
                          config=inference_config,
                          model_dir=ROOT_DIR)

# Load trained weights (fill in path to trained weights here)
assert model_path != "", "Provide path to trained weights"
print("Loading weights from ", model_path)
model.load_weights(model_path, by_name=True)
# Out:
# WARNING:tensorflow:From /Pneumonia_Detection/Mask_RCNN/mrcnn/model.py:772: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Loading weights from  /Pneumonia_Detection/working/pneumonia20190504T2159/mask_rcnn_pneumonia_0028.h5
# Re-starting from epoch 28

# %%
# set color for class
def get_colors_for_class_ids(class_ids):
    colors = []
    for class_id in class_ids:
        if class_id == 1:
            colors.append((.941, .204, .204))
    return colors

# %%
# Show few example of ground truth vs. predictions on the validation dataset 
dataset = dataset_val
fig = plt.figure(figsize=(10, 30))

for i in range(4):

    image_id = random.choice(dataset.image_ids)
    
    original_image, image_meta, gt_class_id, gt_bbox, gt_mask =\
        modellib.load_image_gt(dataset_val, inference_config, 
                               image_id, use_mini_mask=False)
        
    plt.subplot(6, 2, 2*i + 1)
    visualize.display_instances(original_image, gt_bbox, gt_mask, gt_class_id, 
                                dataset.class_names,
                                colors=get_colors_for_class_ids(gt_class_id), ax=fig.axes[-1])
    
    plt.subplot(6, 2, 2*i + 2)
    results = model.detect([original_image]) #, verbose=1)
    r = results[0]
    visualize.display_instances(original_image, r['rois'], r['masks'], r['class_ids'], 
                                dataset.class_names, r['scores'], 
                                colors=get_colors_for_class_ids(r['class_ids']), ax=fig.axes[-1])
# Out:
# *** No instances to display ***
#
#
# *** No instances to display ***
#
#
# *** No instances to display ***
#
#
# *** No instances to display ***

# %%
# Get filenames of test dataset DICOM images
test_image_fps = get_dicom_fps(test_dicom_dir)

# %%
# Make predictions on test images, write out sample submission
def predict(image_fps, filepath='submission.csv', min_conf=0.95):
    # assume square image
    resize_factor = ORIG_SIZE / config.IMAGE_SHAPE[0]
    #resize_factor = ORIG_SIZE
    with open(filepath, 'w') as file:
        file.write("patientId,PredictionString\n")

        for image_id in tqdm(image_fps):
            ds = pydicom.read_file(image_id)
            image = ds.pixel_array
            # If grayscale. Convert to RGB for consistency.
            if len(image.shape) != 3 or image.shape[2] != 3:
                image = np.stack((image,) * 3, -1)
            image, window, scale, padding, crop = utils.resize_image(
                image,
                min_dim=config.IMAGE_MIN_DIM,
                min_scale=config.IMAGE_MIN_SCALE,
                max_dim=config.IMAGE_MAX_DIM,
                mode=config.IMAGE_RESIZE_MODE)

            patient_id = os.path.splitext(os.path.basename(image_id))[0]

            results = model.detect([image])
            r = results[0]

            out_str = ""
            out_str += patient_id
            out_str += ","
            assert( len(r['rois']) == len(r['class_ids']) == len(r['scores']) )
            if len(r['rois']) == 0:
                pass
            else:
                num_instances = len(r['rois'])

                for i in range(num_instances):
                    if r['scores'][i] > min_conf:
                        out_str += ' '
                        out_str += str(round(r['scores'][i], 2))
                        out_str += ' '

                        # x1, y1, width, height
                        x1 = r['rois'][i][1]
                        y1 = r['rois'][i][0]
                        width = r['rois'][i][3] - x1
                        height = r['rois'][i][2] - y1
                        bboxes_str = "{} {} {} {}".format(x1*resize_factor, y1*resize_factor, \
                                                           width*resize_factor, height*resize_factor)
                        out_str += bboxes_str

            file.write(out_str+"\n")

# %%
submission_fp = os.path.join(ROOT_DIR, 'submission.csv')
predict(test_image_fps, filepath=submission_fp)
print(submission_fp)
# Out:
# 100%|██████████| 3000/3000 [06:32<00:00,  7.78it/s]
# /Pneumonia_Detection/submission.csv

# %%
output = pd.read_csv(submission_fp)
output.head(3000)
# Out:
#                                  patientId  \
# 0     2565d222-7628-442d-ae1f-af5cfab84559
# 1     011df306-5ca7-442e-bd54-f05820d84396
# 2     1a6143c0-f2ea-4858-9983-87fb497307ed
# 3     1b4555aa-bfe4-4bc5-aaee-8c4347d3cbb5
# 4     2995760c-95b6-4c79-b6ad-c15316de38e1
# 5     bfec16e6-874f-4083-954e-7031d559f05e
# 6     2cfc1c2d-5de1-45f5-b7a0-d225a6bf186a
# 7     1382da13-c9ae-49a3-8919-2ae412553fa7
# 8     14d4b142-29d6-4656-ab1d-17b84816b2c6
# 9     2676fc9d-7ace-4896-b698-17fc68131851
# 10    c141f676-7ac5-4231-bdb2-aea92772eb7f
# 11    2e69c952-c3a8-492e-aa98-c3a8de18dc09
# 12    012d2cf2-f973-4bf1-934f-295df6e44b60
# 13    219d76a5-44b8-4e95-b651-d638661b89ec
# 14    114bf6af-d3ef-489c-a6fe-304f7ef36fd0
# 15    1f68a1f7-8f1a-4ff1-ae74-c85ff1567ad6
# 16    2996eb94-ba9c-4d89-a9f4-531a15fec52f
# 17    30b596fe-fdf8-404c-9d3c-11341fd91ee5
# 18    0da4074c-fa4b-4450-81b3-74282d6c49a6
# 19    00af3668-1970-4f65-a292-525d2c5aed5c
# 20    02697c06-6d28-49ec-a66e-2eeafeb19358
# 21    03a37eda-cff4-4ad9-b5d7-5f9ab9dbbfe3
# 22    24a37027-3bb6-4827-8d70-cdc74d5f40db
# 23    2efd4438-6385-4c97-8869-82c83e739756
# 24    1b039597-aeb2-4409-b39d-df8729c46c56
# 25    2bb5fb3e-0a7d-42c1-bec3-bf86f6fe4029
# 26    306046b1-6d19-42f0-8cde-98c84f923afa
# 27    1b90407a-e937-47f8-8cf1-8f801733b78b
# 28    2716e765-3e72-4a19-9486-ae163413958c
# 29    057a7499-4836-44ef-9490-56b002cd63c2
# ...                                    ...
# 2970  143cc465-80b8-484c-ba71-ad362ea8fd90
# 2971  c19eb270-ac17-48f3-bc22-9ba6fd38ac52
# 2972  1bfc882d-8bb0-4032-820a-4c34e5790ad6
# 2973  1a6d0d55-8031-4e17-8c1c-d2023eb0a99e
# 2974  2745d0fe-c25e-46fc-b9c6-05ec96f9346a
# 2975  273bdee2-1dd4-4dd2-a29b-92a29023f6d3
# 2976  28bc3690-8ccf-4baa-8237-fbbd4b8ece72
# 2977  2ac2f354-ae86-4c87-9ed7-38c842c6e604
# 2978  12934bb0-bf43-4ba0-ab27-718c338f2c63
# 2979  2c4d9d50-bb03-4d73-b972-4f9ca8b90661
# 2980  2fbceaa4-7df5-499c-bab7-f7f75f56a817
# 2981  19d5680e-aca6-4a97-9e07-2302a66e969f
# 2982  116fee2c-9f15-401a-8a7f-c260a6f5a8e0
# 2983  2b07bf92-761f-409c-9f56-d85fd0b33a43
# 2984  10c41e0f-35e9-4bd2-863f-4b7a69cede01
# 2985  286c2c78-1a39-4fc9-96ab-90d496c54a4f
# 2986  c14ca401-87c1-4ab2-9aa7-7f8bec9f0c06
# 2987  29f74eff-c4f5-49d7-9ef8-fdb051100539
# 2988  1016f480-01f3-41ca-8b3d-5f6d76b28db7
# 2989  25b48729-772e-4742-80fa-3763b787d87d
# 2990  2decd097-e919-4dad-a2cc-a3a6e4062efd
# 2991  0eb58a9b-834f-4962-abfa-5c13b8a4b3cc
# 2992  116d7d17-9c3c-4e2a-99ab-cf3ac9d223d5
# 2993  037baafe-07de-49e7-ae6b-2fac90640f0b
# 2994  014ae099-4762-46d3-a3b9-7fd25e3337c0
# 2995  22669933-5680-4544-a22d-08f7875d2d3f
# 2996  2ff9e61f-1666-4ea2-b649-66ba3d71377e
# 2997  2634cbd2-0a3f-4503-bc07-b8f4f2da80c4
# 2998  235ed51f-2494-47fe-97a4-fdbefc03cb07
# 2999  214d9224-97dd-470a-abd6-59d756228452
#
#                                        PredictionString
# 0                          0.99 232.0 376.0 216.0 272.0
# 1                          0.96 352.0 368.0 120.0 140.0
# 2                          0.97 568.0 340.0 252.0 608.0
# 3      0.97 644.0 548.0 152.0 152.0 0.97 284.0 564.0...
# 4                                                   NaN
# 5      0.97 528.0 292.0 260.0 476.0 0.97 152.0 272.0...
# 6                          0.95 244.0 420.0 256.0 204.0
# 7                          0.96 588.0 404.0 252.0 388.0
# 8                          0.98 164.0 208.0 228.0 300.0
# 9      0.98 92.0 312.0 288.0 500.0 0.97 556.0 456.0 ...
# 10     0.98 216.0 352.0 180.0 220.0 0.96 584.0 476.0...
# 11                                                  NaN
# 12                         0.97 644.0 176.0 224.0 496.0
# 13                         0.98 544.0 396.0 240.0 392.0
# 14     0.99 212.0 276.0 244.0 476.0 0.96 596.0 264.0...
# 15     0.97 616.0 612.0 116.0 140.0 0.95 268.0 600.0...
# 16                                                  NaN
# 17     0.98 556.0 256.0 248.0 488.0 0.95 180.0 224.0...
# 18     0.98 268.0 284.0 256.0 460.0 0.98 552.0 344.0...
# 19                                                  NaN
# 20     0.98 216.0 468.0 204.0 184.0 0.96 608.0 520.0...
# 21     0.97 140.0 344.0 276.0 348.0 0.96 568.0 432.0...
# 22                         0.98 204.0 360.0 224.0 364.0
# 23     0.97 212.0 448.0 168.0 140.0 0.97 584.0 424.0...
# 24     0.96 268.0 248.0 232.0 576.0 0.96 664.0 368.0...
# 25                                                  NaN
# 26                         0.96 140.0 188.0 288.0 636.0
# 27     0.96 604.0 220.0 292.0 480.0 0.95 228.0 344.0...
# 28     0.97 228.0 324.0 204.0 300.0 0.97 544.0 240.0...
# 29     0.99 564.0 220.0 276.0 552.0 0.97 188.0 160.0...
# ...                                                 ...
# 2970                       0.97 200.0 224.0 260.0 560.0
# 2971                                                NaN
# 2972                       0.96 172.0 356.0 228.0 516.0
# 2973                                                NaN
# 2974   0.96 272.0 364.0 240.0 280.0 0.95 672.0 204.0...
# 2975                       0.96 604.0 308.0 264.0 284.0
# 2976   0.97 652.0 456.0 252.0 364.0 0.97 684.0 288.0...
# 2977   0.97 588.0 456.0 124.0 148.0 0.96 180.0 320.0...
# 2978                                                NaN
# 2979   0.98 140.0 292.0 248.0 340.0 0.96 588.0 372.0...
# 2980   0.98 360.0 452.0 260.0 312.0 0.96 744.0 492.0...
# 2981                       0.97 168.0 440.0 248.0 268.0
# 2982   0.99 224.0 228.0 272.0 492.0 0.98 628.0 272.0...
# 2983   0.99 208.0 436.0 232.0 288.0 0.98 600.0 308.0...
# 2984                       0.98 608.0 448.0 232.0 404.0
# 2985                       0.98 212.0 480.0 256.0 216.0
# 2986                       0.97 200.0 380.0 256.0 272.0
# 2987                       0.98 188.0 268.0 220.0 448.0
# 2988                                                NaN
# 2989                       0.97 584.0 508.0 164.0 140.0
# 2990                       0.98 288.0 432.0 164.0 160.0
# 2991                       0.98 196.0 592.0 176.0 144.0
# 2992                       0.97 244.0 748.0 136.0 132.0
# 2993                                                NaN
# 2994                       0.97 204.0 380.0 296.0 248.0
# 2995   0.98 224.0 416.0 212.0 332.0 0.96 600.0 496.0...
# 2996                       0.96 120.0 544.0 264.0 328.0
# 2997                       0.95 240.0 540.0 188.0 312.0
# 2998   0.98 576.0 532.0 108.0 180.0 0.96 144.0 404.0...
# 2999                                                NaN
#
# [3000 rows x 2 columns]

# %%
files.download(submission_fp)
